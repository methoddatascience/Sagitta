# %%
from operator import add
from pyspark.ml.feature import RegexTokenizer, CountVectorizer
from pyspark.ml.feature import StopWordsRemover, VectorAssembler
from pyspark.ml.feature import Word2Vec, Word2VecModel
from pyspark.ml.feature import IDF
from pyspark.ml import Pipeline, PipelineModel

from pyspark.sql.functions import *
from pyspark.sql.types import *

from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession
#sc = SparkContext(gateway = jg.launch_gateway())

import folium
import html

import pandas as pd
import numpy as np

# %%
data_path = '/Volumes/Transcend/dataset/'
model_path = '/Volumes/Transcend/MDS_Yelp/model/'
outout_path = '/Volumes/Transcend/MDS_Yelp/output/'

# %%
sc.stop()

# %%
sc = SparkContext()
#sc = SparkContext('local')
spark = SparkSession(sc)

# %%
business_df = spark.read.parquet(data_path + 'business-small.parquet')
business_df.printSchema()
# Out:
# root
#  |-- business_id: string (nullable = true)
#  |-- business_name: string (nullable = true)
#  |-- neighborhood: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- postal_code: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- stars: double (nullable = true)
#  |-- review_count: long (nullable = true)
#  |-- categories: array (nullable = true)
#  |    |-- element: string (containsNull = true)

# %%
user_df = spark.read.parquet(data_path + 'user-small.parquet')
user_df.printSchema()
# Out:
# root
#  |-- user_id: string (nullable = true)
#  |-- user_name: string (nullable = true)
#  |-- review_count: long (nullable = true)
#  |-- yelping_since: string (nullable = true)
#  |-- useful: long (nullable = true)
#  |-- funny: long (nullable = true)
#  |-- cool: long (nullable = true)
#  |-- fans: long (nullable = true)
#  |-- average_stars: double (nullable = true)

# %%
review_df = spark.read.parquet(data_path + 'review-small.parquet')
review_df.printSchema()
# Out:
# root
#  |-- review_id: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- business_id: string (nullable = true)
#  |-- stars: long (nullable = true)
#  |-- review_date: string (nullable = true)
#  |-- review_text: string (nullable = true)
#  |-- useful: long (nullable = true)
#  |-- funny: long (nullable = true)
#  |-- cool: long (nullable = true)

# %%
# create SQL view for later queries
review_df.createOrReplaceTempView("reviews")

# create review text dataframe
reviews_text = spark.sql("SELECT user_id, review_text FROM reviews")
reviews_text.show(3)
# Out:
# +--------------------+--------------------+
# |             user_id|         review_text|
# +--------------------+--------------------+
# |u0LXt3Uea_GidxRW1...|Who would have gu...|
# |u0LXt3Uea_GidxRW1...|Not bad!! Love th...|
# |u0LXt3Uea_GidxRW1...|This is currently...|
# +--------------------+--------------------+
# only showing top 3 rows

# %%
# concatenate all reviews per restuarant

reviews_text_rdd = reviews_text.rdd
reviews_by_user_rdd = reviews_text_rdd.map(tuple).reduceByKey(add)  
reviews_by_user_df = spark.createDataFrame(reviews_by_user_rdd)
reviews_by_user_df = reviews_by_user_df \
                            .withColumnRenamed('_1', 'user_id') \
                            .withColumnRenamed('_2', 'text')
reviews_by_user_df.count()
# Out:
# 73041

# %%
## Example of using Word2vec
from pyspark.ml.feature import Word2Vec

# Input data: Each row is a bag of words from a sentence or document.
documentDF = spark.createDataFrame([
    ("Hi I heard about Spark".split(" "), ),
    ("I wish Java could use case classes".split(" "), ),
    ("Logistic regression models are neat".split(" "), )
], ["text"])

# Learn a mapping from words to Vectors.
word2Vec = Word2Vec(vectorSize=3, minCount=0, inputCol="text", outputCol="result")
model = word2Vec.fit(documentDF)

result = model.transform(documentDF)
for row in result.collect():
    text, vector = row
    print("Text: [%s] => \nVector: %s\n" % (", ".join(text), str(vector)))
# Out:
# Text: [Hi, I, heard, about, Spark] =>
# Vector: [0.02326762331649661,0.008931299671530724,-0.06394885405898094]
#
# Text: [I, wish, Java, could, use, case, classes] =>
# Vector: [-0.009175857529044151,-0.024911361613443917,0.012272004171141555]
#
# Text: [Logistic, regression, models, are, neat] =>
# Vector: [-0.005160079896450043,-0.0005152661353349686,0.014656295813620091]

# %%
## https://spark.apache.org/docs/latest/api/python/pyspark.ml.html#pyspark.ml.feature.Word2Vec

## The minimum number of times a token must appear to be included in the word2vec model's vocabulary"

# %%
# %%time
# usefule link: https://www.tutorialkart.com/apache-spark/spark-mllib-tf-idf/
# create text processing pipeline -- this a lengthy resource-intensive process
# Build the pipeline 
regexTokenizer = RegexTokenizer(gaps = False, pattern = '\w+', inputCol = 'text', outputCol = 'token')
stopWordsRemover = StopWordsRemover(inputCol = 'token', outputCol = 'nostopwrd')
countVectorizer = CountVectorizer(inputCol="nostopwrd", outputCol="rawFeature")
iDF = IDF(inputCol="rawFeature", outputCol="idf_vec")
# TD-IDF Vec
word2Vec = Word2Vec(vectorSize = 100, minCount = 5, inputCol = 'nostopwrd', outputCol = 'word_vec', seed=123)
vectorAssembler = VectorAssembler(inputCols=['idf_vec', 'word_vec'], outputCol='comb_vec')
pipeline = Pipeline(stages=[regexTokenizer, stopWordsRemover, countVectorizer, iDF, word2Vec, vectorAssembler])

# fit the model
pipeline_mdl = pipeline.fit(reviews_by_user_df)

#save the pipeline model
pipeline_mdl.write().overwrite().save(model_path + 'pipe_txt')

# %%
# load the text transformation pipeline trained model
pipeline_mdl = PipelineModel.load(model_path + 'pipe_txt')

# %%
# transform the review data
reviews_by_user_trf_df = pipeline_mdl.transform(reviews_by_user_df)

# %%
# show the transformed review data
reviews_by_user_trf_df.select( 'text', 'nostopwrd', 'idf_vec', 'word_vec', 'comb_vec').show(10)
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+
# |                text|           nostopwrd|             idf_vec|            word_vec|            comb_vec|
# +--------------------+--------------------+--------------------+--------------------+--------------------+
# |A born and bred T...|[born, bred, toro...|(128365,[0,1,2,3,...|[-0.0298230579082...|(128465,[0,1,2,3,...|
# |I have never done...|[never, done, one...|(128365,[2,6,11,1...|[-0.0256846508636...|(128465,[2,6,11,1...|
# |What a find!  I'm...|[find, m, almost,...|(128365,[2,3,6,11...|[-0.0783052189961...|(128465,[2,3,6,11...|
# |Not impressed wit...|[impressed, place...|(128365,[0,1,2,3,...|[-0.0273270801487...|(128465,[0,1,2,3,...|
# |Very tight space....|[tight, space, fo...|(128365,[2,39,116...|[-0.0261619807634...|(128465,[2,39,116...|
# |While in Toronto ...|[toronto, last, w...|(128365,[0,1,2,3,...|[-0.0836421314076...|(128465,[0,1,2,3,...|
# |I loved the decor...|[loved, decor, re...|(128365,[0,1,3,5,...|[-0.0428024260223...|(128465,[0,1,3,5,...|
# |Amazing vermacell...|[amazing, vermace...|(128365,[0,2,4,5,...|[-0.1015487008305...|(128465,[0,2,4,5,...|
# |Uncle Tetsu's is ...|[uncle, tetsu, ho...|(128365,[0,1,2,4,...|[-0.0397153475544...|(128465,[0,1,2,4,...|
# |Love this place! ...|[love, place, eve...|(128365,[0,1,2,3,...|[0.00909978398385...|(128465,[0,1,2,3,...|
# +--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 10 rows

# %%
def CosineSim(vec1, vec2): 
    return np.dot(vec1, vec2) / np.sqrt(np.dot(vec1, vec1)) / np.sqrt(np.dot(vec2, vec2))

# %%
all_user_vecs = reviews_by_user_trf_df.select('user_id', 'word_vec').rdd.map(lambda x: (x[0], x[1])).collect()

# %% [raw]
# def toCSVLine(data):
#     return(','.join(str(d) for d in data))
#
# lines = rdd_odj.map(toCSVLine)
# lines.saveAsTextFile('rdd_file_to_csv.csv')

# %% [raw]
# import pickle
#
# #with open("all_user_vecs.txt", "wb") as fp:   #Pickling
# #    pickle.dump(all_user_vecs, fp)
#
# with open("all_user_vecs.txt", "rb") as fp:   # Unpickling
#     all_user_vecs = pickle.load(fp)

# %%
all_user_vecs[0]
# user_id = 'nOTl4aPC4tKHK35T3bNauQ'
# DenseVector() - vector respresentation of all the reviews of User
# Out:
# ('BytRWk8X1OelSgwwfXd8Aw',
#  DenseVector([-0.0298, -0.0741, -0.0649, 0.0832, 0.0279, -0.0149, -0.0436, -0.0123, -0.0076, -0.0379, -0.0085, -0.0369, -0.0037, -0.0116, 0.0142, -0.0317, -0.0555, -0.0272, -0.0729, 0.0104, -0.0666, -0.0442, 0.0158, 0.0029, 0.0563, -0.0458, -0.0137, -0.0207, -0.0063, 0.0337, 0.0583, 0.0148, 0.0212, -0.0019, -0.031, -0.0436, 0.0617, 0.0352, -0.0151, -0.0433, -0.0319, -0.0212, -0.0246, 0.0944, 0.0214, -0.0364, -0.0363, 0.0447, 0.0029, 0.0008, 0.0107, -0.0229, -0.0219, -0.045, -0.0714, 0.0296, 0.0166, 0.0181, 0.0324, -0.0024, -0.0046, 0.0065, 0.0301, -0.049, -0.0385, 0.0413, 0.0566, 0.0437, -0.0322, 0.0902, -0.0098, -0.0056, 0.0242, 0.0346, 0.0133, -0.0412, -0.0373, 0.0083, -0.0207, 0.0461, -0.0175, -0.0269, 0.0018, -0.0071, -0.0001, 0.0023, 0.0449, 0.0108, 0.0087, 0.0074, 0.013, -0.0001, -0.0442, 0.0266, -0.0158, -0.0175, -0.0496, 0.0423, -0.0899, 0.034]))

# %%
def getSimilarUsers(u_ids, all_user_vecs, sim_user_limit=10):
    
    schema = StructType([   
                            StructField("user_id", StringType(), True)
                            ,StructField("score", IntegerType(), True)
                            ,StructField("input_user_id", StringType(), True)
                        ])
    
    similar_user_df = spark.createDataFrame([], schema)
    similar_user_df_all = spark.createDataFrame([], schema)
    
    for u_id in u_ids:
        input_vec = [(r[1]) for r in all_user_vecs if r[0] == u_id]
        if(len(input_vec) < 1):
            print("not in the user_df")
            break
        else:
            #print("-------------------------------")
            #print(u_id)
            input_vec = input_vec[0]
    
        similar_user_rdd = sc.parallelize((i[0], float(CosineSim(input_vec, i[1]))) for i in all_user_vecs)
        
        similar_user_df = spark.createDataFrame(similar_user_rdd) \
            .withColumnRenamed('_1', 'user_id') \
            .withColumnRenamed('_2', 'score') \
            .orderBy("score", ascending = False)
            
        similar_user_df = similar_user_df.dropna()    
        similar_user_df = similar_user_df.filter(col("user_id") != u_id).limit(sim_user_limit)
        similar_user_df = similar_user_df.withColumn('input_user_id', lit(u_id))
        
        similar_user_df = similar_user_df \
                                    .union(similar_user_df)
        
        similar_user_df_all = similar_user_df_all.union(similar_user_df)
    similar_user_df_all = similar_user_df_all.dropDuplicates()    
    return similar_user_df_all

# %%
def getUserDetails(user):
    
    a = user.alias("a")
    b = user_df.alias("b")
    
    return a.join(b, col("a.user_id") == col("b.user_id"), 'inner') \
             .select([col('a.'+xx) for xx in a.columns] + [col('b.user_id'), col('b.user_name'),col('b.review_count')])

# %%
# test with two users

uids = ['nOTl4aPC4tKHK35T3bNauQ', 'QBac9-Ii6jR-yLsQ5MVTHg']

print('\ninput user details:')
user_df.select('user_id','user_name', 'review_count') \
    .filter(user_df.user_id.isin(uids) == True).show(truncate=False)
    
# get top 10 similar users
sim_users = getUserDetails(getSimilarUsers(uids, all_user_vecs, 10))

print('Top 10 similar Users for each input restaurant are:"')
sim_users_df = sim_users.select('input_user_id', 'a.user_id', 'user_name', 'score','review_count').toPandas()
sim_users_df
# Out:
# input user details:
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |nOTl4aPC4tKHK35T3bNauQ|Katherine|148         |
# |QBac9-Ii6jR-yLsQ5MVTHg|Alex     |13          |
# +----------------------+---------+------------+
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in double_scalars
# Top 10 similar Users for each input restaurant are:"
#              input_user_id                 user_id user_name     score  \
# 0   QBac9-Ii6jR-yLsQ5MVTHg  J5Eb7LhJaOa20k0ppcOCOg      Alek  0.907664
# 1   nOTl4aPC4tKHK35T3bNauQ  ZBllYKrFzaI0I7v6Wl26Wg   Cecilia  0.963999
# 2   QBac9-Ii6jR-yLsQ5MVTHg  cNhHuEQMIpLH_qc9qGz67A       Jay  0.910774
# 3   QBac9-Ii6jR-yLsQ5MVTHg  _IR48ok0ZkPMWJ2PlRCk0A   Michael  0.907098
# 4   nOTl4aPC4tKHK35T3bNauQ  myrcQ3h2G04Gv-ANG_oqrg     Linda  0.971381
# 5   QBac9-Ii6jR-yLsQ5MVTHg  MpN81tQOL86GaFse-_tTRQ       Amy  0.913263
# 6   QBac9-Ii6jR-yLsQ5MVTHg  kw-YtOKPXrRB2a9wRZlmzQ     Jimmy  0.915453
# 7   nOTl4aPC4tKHK35T3bNauQ  uO1w3qNo21c1bVHHFTYW0w    Joanne  0.972255
# 8   QBac9-Ii6jR-yLsQ5MVTHg  bPUpO-bP6BmAGvSwPyDsng   Michael  0.905848
# 9   nOTl4aPC4tKHK35T3bNauQ  PGx4HvY5joEeqXzam6tO7A      Lisa  0.965808
# 10  nOTl4aPC4tKHK35T3bNauQ  VVm-TFCpi9M1-k8ED0l1eA   Juliana  0.971013
# 11  QBac9-Ii6jR-yLsQ5MVTHg  xcBcIMVWEx1p7V8ACaeHpQ      Rick  0.918668
# 12  nOTl4aPC4tKHK35T3bNauQ  yL60onlTh1BmJKVLli_K3g  Danielle  0.964604
# 13  nOTl4aPC4tKHK35T3bNauQ  vJGLEHyhCs9V-5fAe-xx3w      Lisa  0.968622
# 14  nOTl4aPC4tKHK35T3bNauQ  v1nRL_f2EQs7fjh_m0TdQQ     Bryan  0.969187
# 15  nOTl4aPC4tKHK35T3bNauQ  n4usc2DF4pd9fdi2wLDloQ    Lidiya  0.964592
# 16  QBac9-Ii6jR-yLsQ5MVTHg  g5W7s0n19gvT1Ujy_ITJog      Bria  0.907846
# 17  nOTl4aPC4tKHK35T3bNauQ  USUw_VT31ygQ9JkEc6nPsg        NJ  0.965363
# 18  QBac9-Ii6jR-yLsQ5MVTHg  eV5usRjY2cDqNKVv8wXroA       Sam  0.905077
# 19  QBac9-Ii6jR-yLsQ5MVTHg  zkKv10FEw-iWJBHvK0mGfA      Paul  0.903733
#
#     review_count
# 0             34
# 1            135
# 2             57
# 3             82
# 4            112
# 5             46
# 6            101
# 7            221
# 8            142
# 9            349
# 10           442
# 11            83
# 12           264
# 13           334
# 14            33
# 15           343
# 16            73
# 17            90
# 18           105
# 19            55

# %% [raw]
# pd_review_df = review_df.toPandas()

# %%
review = pd.read_csv("/Volumes/Transcend/MDS_Yelp/yelp_review.csv")

# %%
#uids = ['nOTl4aPC4tKHK35T3bNauQ', 'QBac9-Ii6jR-yLsQ5MVTHg']
review_uid1 = review.loc[review['user_id'].isin(['nOTl4aPC4tKHK35T3bNauQ'])]
review_uid2 = review.loc[review['user_id'].isin(['PGx4HvY5joEeqXzam6tO7A'])]
merged_uid = pd.merge(review_uid1, review_uid2, how = 'inner', on = 'business_id')
merged_uid[['business_id', 'stars_x', 'stars_y', 'text_x', 'text_y', 'date_x', 'date_y']] 
#average the rating if more than 1 review

# %%
import fastparquet
review_df = pd.read_parquet(data_path + 'review-small.parquet', engine='fastparquet')

# %%
review_uid1 = review.loc[review['user_id'].isin(['nOTl4aPC4tKHK35T3bNauQ'])]
review_uid2 = review.loc[review['user_id'].isin(['vJGLEHyhCs9V-5fAe-xx3w'])]
merged_uid = pd.merge(review_uid1, review_uid2, how = 'inner', on = 'business_id')
merged_uid[['business_id', 'stars_x', 'stars_y', 'text_x', 'text_y', 'date_x', 'date_y']] #average the rating if more than 1 review
# Out:
#               business_id  stars_x  stars_y  \
# 0  oQylTvXwGIkKFdCjmafKVg        4        4
# 1  5N8R7ALESZ30EoAzVJtabw        5        5
# 2  u2ETlHOcFdRz4BxcdfsK0Q        3        3
#
#                                               text_x  \
# 0  We went here after dinner, simply for drinks. ...
# 1  Went in on a whim and was not disappointed. I ...
# 2  We went here for Summerlicious. For $25 we got...
#
#                                               text_y      date_x      date_y
# 0  We came here for Mother's day as has become tr...  2013-02-10  2013-06-04
# 1  The Dirty Bird invited me back to give them an...  2016-10-17  2015-10-15
# 2  I came here for a ladies lunch with the girls ...  2012-07-08  2013-06-04

# %%
review_uid1 = review.loc[review['user_id'].isin(['nOTl4aPC4tKHK35T3bNauQ'])]
review_uid2 = review.loc[review['user_id'].isin(['ZBllYKrFzaI0I7v6Wl26Wg'])]
merged_uid = pd.merge(review_uid1, review_uid2, how = 'inner', on = 'business_id')
merged_uid[['business_id', 'stars_x', 'stars_y', 'text_x', 'text_y', 'date_x', 'date_y']] #average the rating if more than 1 review
# Out:
#               business_id  stars_x  stars_y  \
# 0  cefRDEK5O3t_iUuwnmL27Q        4        4
# 1  c78Pat78fVUBFPXYeVvbaQ        5        3
#
#                                               text_x  \
# 0  We booked a reservation at Smith for Summerlic...
# 1  I am surprised at the people complaining about...
#
#                                               text_y      date_x      date_y
# 0  I would've given it 5 stars for the food, but ...  2012-07-12  2014-05-05
# 1  Overrated. \n\nMistake: coming to Odd Seoul on...  2016-01-24  2016-03-01

# %%
review_uid1 = review.loc[review['user_id'].isin(['nOTl4aPC4tKHK35T3bNauQ'])]
review_uid2 = review.loc[review['user_id'].isin(['VVm-TFCpi9M1-k8ED0l1eA'])]
merged_uid = pd.merge(review_uid1, review_uid2, how = 'inner', on = 'business_id')
merged_uid[['business_id', 'stars_x', 'stars_y', 'text_x', 'text_y', 'date_x', 'date_y']] #average the rating if more than 1 review
# Out:
#               business_id  stars_x  stars_y  \
# 0  zgQHtqX0gqMw1nlBZl2VnQ        2        4
# 1  kGOr_D-LNpgZ2M9N8TT4QQ        5        4
# 2  W5d8iNog90R-qw43m5dGwg        5        5
# 3  OIdOJaNS8M624F58XGV3PQ        4        3
#
#                                               text_x  \
# 0  While I really enjoyed the noodles, their sign...
# 1  I went here with my husband and another couple...
# 2  I have been craving schnitzel for a LONG time,...
# 3  Really this deserves a 3-1\/2 star rating, but...
#
#                                               text_y      date_x      date_y
# 0  Actual rating 3.5\n\nLet's get my main gripe o...  2013-10-19  2014-11-22
# 1  La Societe looks as good as you'd imagine a re...  2013-01-27  2012-01-05
# 2  Had lunch here today and I'm totally sold.  Si...  2012-10-08  2012-08-12
# 3  Actually around 3.5\n\nHaven't been here in qu...  2012-11-11  2014-12-22

# %%
review_uid1 = review.loc[review['user_id'].isin(['QBac9-Ii6jR-yLsQ5MVTHg'])]
review_uid2 = review.loc[review['user_id'].isin(['eV5usRjY2cDqNKVv8wXroA'])]
merged_uid = pd.merge(review_uid1, review_uid2, how = 'inner', on = 'business_id')
merged_uid[['business_id', 'stars_x', 'stars_y', 'text_x', 'text_y', 'date_x', 'date_y']] #average the rating if more than 1 review
# Out:
#               business_id  stars_x  stars_y  \
# 0  r_BrIgzYcwo1NAuG9dLbpg        4        3
#
#                                               text_x  \
# 0  This review will be shorter than my first two....
#
#                                               text_y      date_x      date_y
# 0  Total cheap eat hipster restaurant. The food w...  2016-07-05  2016-05-02

# %% [markdown]
# ##### Using combination vector of Word2Vec and IDF

# %% [raw]
# all_user_idfvecs = reviews_by_user_trf_df.select('user_id', 'idf_vec').rdd.map(lambda x: (x[0], x[1])).collect()

# %% [markdown]
# ##### top users from user-business-set notebook

# %%
# converting to pandas dataframe
user_pd = user_df.toPandas()
user_pd = user_pd.sort_values(by = 'review_count', ascending= False)
uids_top_500 = list(user_pd.user_id.iloc[0:500])
user_pd.head()
# Out:
#                       user_id user_name  review_count yelping_since  useful  \
# 54601  8RcEwGrFIgkt9WQ35E6SnQ    George          7764    2009-11-06     123
# 44835  Xwnf20FKuikiHcSpcEbpKQ   Kenneth          6653    2011-06-10    1444
# 22639  CxDOIDnH8gp9KXzpBHJYXw  Jennifer          5868    2009-11-09    1241
# 48114  HFECrzYDpgbS5EmTBtj2zQ      Eric          5344    2007-03-28    3905
# 29361  Hi10sGSZNxQH3NLyWSZ1oA       Fox          4537    2009-05-26   40103
#
#        funny   cool  fans  average_stars
# 54601    139    113   272           3.49
# 44835   1142   1167   237           3.32
# 22639   1968    959   610           3.29
# 48114   3876   3847   397           3.93
# 29361  40030  39837   871           3.81

# %%
sim_users_all = pd.DataFrame(columns = ['input_user_id', 'user_id', 'user_name', 'score', 'review_count'])

# %%
iterator = 0
for uid in uids_top_500:
    user_df.select('user_id','user_name', 'review_count') \
            .filter(user_df.user_id.isin([uid]) == True).show(truncate=False)

    sim_users = getUserDetails(getSimilarUsers([uid], all_user_vecs, 10))
    sim_users_pd = sim_users.select('input_user_id', 'a.user_id', 'user_name', 'score','review_count').toPandas()
    sim_users_all = pd.concat([sim_users_all, sim_users_pd])
    sim_users_all = sim_users_all.drop_duplicates()
    sim_users_all = sim_users_all.sort_values(by = 'input_user_id')
    iterator = iterator + 1
    print(iterator)
    if iterator > 20:
        sim_users_all.to_csv("sim_users_200.csv")

with open("sim_users_200.txt", "wb") as fp:   #Pickling
    pickle.dump(sim_users_all, fp)

sim_users_all.to_csv("sim_users_500.csv")
# Out:
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |8RcEwGrFIgkt9WQ35E6SnQ|George   |7764        |
# +----------------------+---------+------------+
#
# 8RcEwGrFIgkt9WQ35E6SnQ
# 1
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in double_scalars
# 1
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |Xwnf20FKuikiHcSpcEbpKQ|Kenneth  |6653        |
# +----------------------+---------+------------+
#
# Xwnf20FKuikiHcSpcEbpKQ
# 1
# 2
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |CxDOIDnH8gp9KXzpBHJYXw|Jennifer |5868        |
# +----------------------+---------+------------+
#
# CxDOIDnH8gp9KXzpBHJYXw
# 1
# 3
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |HFECrzYDpgbS5EmTBtj2zQ|Eric     |5344        |
# +----------------------+---------+------------+
#
# HFECrzYDpgbS5EmTBtj2zQ
# 1
# 4
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |Hi10sGSZNxQH3NLyWSZ1oA|Fox      |4537        |
# +----------------------+---------+------------+
#
# Hi10sGSZNxQH3NLyWSZ1oA
# 1
# 5
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |U4INQZOPSUaj8hMjLlZ3KA|Michael  |4063        |
# +----------------------+---------+------------+
#
# U4INQZOPSUaj8hMjLlZ3KA
# 1
# 6
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |wZPizeBxMAyOSl0M0zuCjg|Jess     |4019        |
# +----------------------+---------+------------+
#
# wZPizeBxMAyOSl0M0zuCjg
# 1
# 7
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |syvwUKQJ4OYfmL_ixVLMeQ|Tina     |3957        |
# +----------------------+---------+------------+
#
# syvwUKQJ4OYfmL_ixVLMeQ
# 1
# 8
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |cMEtAiW60I5wE_vLfTxoJQ|Jennifer |3906        |
# +----------------------+---------+------------+
#
# cMEtAiW60I5wE_vLfTxoJQ
# 1
# 9
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |CQUDh80m48xnzUkx-X5NAw|David    |3734        |
# +----------------------+---------+------------+
#
# CQUDh80m48xnzUkx-X5NAw
# 1
# 10
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |Eypq5gLLjCapBVVnMw_MyA|Misha    |3644        |
# +----------------------+---------+------------+
#
# Eypq5gLLjCapBVVnMw_MyA
# 1
# 11
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |E_GAXhVA1_lVC2aFpMQElA|Alden    |3468        |
# +----------------------+---------+------------+
#
# E_GAXhVA1_lVC2aFpMQElA
# 1
# 12
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |IwHLuykqqmGVNHJ_UCwXWg|Marqus   |3275        |
# +----------------------+---------+------------+
#
# IwHLuykqqmGVNHJ_UCwXWg
# 1
# 13
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |gjhzKWsqCIrpEd9pevbKZw|Miriam   |3138        |
# +----------------------+---------+------------+
#
# gjhzKWsqCIrpEd9pevbKZw
# 1
# 14
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |7JpPvfDAE_14vA1xgFOFjw|Maria    |3118        |
# +----------------------+---------+------------+
#
# 7JpPvfDAE_14vA1xgFOFjw
# 1
# 15
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |WWnhqRnWWjutMqh-2SzEuQ|Steph    |3091        |
# +----------------------+---------+------------+
#
# WWnhqRnWWjutMqh-2SzEuQ
# 1
# 16
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |bQCHF5rn5lMI9c5kEwCaNA|Vincent  |2985        |
# +----------------------+---------+------------+
#
# bQCHF5rn5lMI9c5kEwCaNA
# 1
# 17
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |EiwxlbR8fb68lMgEXhcWKA|Lorrie   |2978        |
# +----------------------+---------+------------+
#
# EiwxlbR8fb68lMgEXhcWKA
# 1
# 18
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |P3usQcIegPCl-cdH4IDirg|Sean     |2816        |
# +----------------------+---------+------------+
#
# P3usQcIegPCl-cdH4IDirg
# 1
# 19
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |w-w-k-QXosIKQ8HQVwU6IQ|Anthony  |2731        |
# +----------------------+---------+------------+
#
# w-w-k-QXosIKQ8HQVwU6IQ
# 1
# 20
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |ZYZNcugF3xUEGyLOVGiZ0Q|Carol    |2718        |
# +----------------------+---------+------------+
#
# ZYZNcugF3xUEGyLOVGiZ0Q
# 1
# 21
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |ITa3vh5ERI90G_WP4SmGUQ|Peter    |2710        |
# +----------------------+---------+------------+
#
# ITa3vh5ERI90G_WP4SmGUQ
# 1
# 22
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |2HchhLgGj16aITZGVy0hqA|Yi       |2705        |
# +----------------------+---------+------------+
#
# 2HchhLgGj16aITZGVy0hqA
# 1
# 23
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |om5ZiponkpRqUNa3pVPiRg|Andrea   |2578        |
# +----------------------+---------+------------+
#
# om5ZiponkpRqUNa3pVPiRg
# 1
# 24
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |kw4Q3Qfj_8WxjTNExSi1hw|Lili     |2518        |
# +----------------------+---------+------------+
#
# kw4Q3Qfj_8WxjTNExSi1hw
# 1
# 25
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |5gbkhlWANGVzQYi_0m3vOQ|Jess     |2441        |
# +----------------------+---------+------------+
#
# 5gbkhlWANGVzQYi_0m3vOQ
# 1
# 26
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |UE-rXhA8njNnADFkDA3EuA|Inigo    |2394        |
# +----------------------+---------+------------+
#
# UE-rXhA8njNnADFkDA3EuA
# 1
# 27
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |QnIrewrXxFnssw_gG1gF-Q|Sarah    |2372        |
# +----------------------+---------+------------+
#
# QnIrewrXxFnssw_gG1gF-Q
# 1
# 28
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |NOUfyJW-BAo_-Cbfo8edww|Lolia    |2363        |
# +----------------------+---------+------------+
#
# NOUfyJW-BAo_-Cbfo8edww
# 1
# 29
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |a4mO387_O77ebmv8AlQB3A|Dave     |2334        |
# +----------------------+---------+------------+
#
# a4mO387_O77ebmv8AlQB3A
# 1
# 30
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |3UIa8YVjETNwJwnOl4SEdg|Vic      |2332        |
# +----------------------+---------+------------+
#
# 3UIa8YVjETNwJwnOl4SEdg
# 1
# 31
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |ZIOCmdFaMIF56FR-nWr_2A|Randy    |2313        |
# +----------------------+---------+------------+
#
# ZIOCmdFaMIF56FR-nWr_2A
# 1
# 32
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |9akppeqi5dnaIqPyJ75aCw|Mimi     |2310        |
# +----------------------+---------+------------+
#
# 9akppeqi5dnaIqPyJ75aCw
# 1
# 33
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |IucvvxdQXXhjQ4z6Or6Nrw|Sunil    |2293        |
# +----------------------+---------+------------+
#
# IucvvxdQXXhjQ4z6Or6Nrw
# 1
# 34
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |iLjMdZi0Tm7DQxX1C1_2dg|Ruggy    |2258        |
# +----------------------+---------+------------+
#
# iLjMdZi0Tm7DQxX1C1_2dg
# 1
# 35
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |PLOYtrCMUFPHQe2IbYAd5g|Joanna   |2203        |
# +----------------------+---------+------------+
#
# PLOYtrCMUFPHQe2IbYAd5g
# 1
# 36
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |fHH6b6yDm1PSoC0G7VPRdA|Ro       |2199        |
# +----------------------+---------+------------+
#
# fHH6b6yDm1PSoC0G7VPRdA
# 1
# 37
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |0Igx-a1wAstiBDerGxXk2A|Jen      |2184        |
# +----------------------+---------+------------+
#
# 0Igx-a1wAstiBDerGxXk2A
# 1
# 38
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |-G7Zkl1wIWBBmD0KRy_sCw|Gerald   |2150        |
# +----------------------+---------+------------+
#
# -G7Zkl1wIWBBmD0KRy_sCw
# 1
# 39
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |kW2dk1CWihmh3g7k9N2G8A|Shradha  |2108        |
# +----------------------+---------+------------+
#
# kW2dk1CWihmh3g7k9N2G8A
# 1
# 40
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |1O638BDK_fWuxgTVJwff-A|Rob      |2071        |
# +----------------------+---------+------------+
#
# 1O638BDK_fWuxgTVJwff-A
# 1
# 41
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |ACUVZ4SiN0gni7dzVDm9EQ|Tiffany  |2038        |
# +----------------------+---------+------------+
#
# ACUVZ4SiN0gni7dzVDm9EQ
# 1
# 42
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |wzyGNvArcpUjZauRWFrKHA|Bill     |2032        |
# +----------------------+---------+------------+
#
# wzyGNvArcpUjZauRWFrKHA
# 1
# 43
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |0G-bcpdR48tfZy6koGUiTQ|Rhea     |2030        |
# +----------------------+---------+------------+
#
# 0G-bcpdR48tfZy6koGUiTQ
# 1
# 44
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |ZpUI9ze0YlA6nMSHwx3ZYQ|Derek    |2027        |
# +----------------------+---------+------------+
#
# ZpUI9ze0YlA6nMSHwx3ZYQ
# 1
# 45
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |d67zTET_2IuVoWcUU0aWaQ|Janet    |2023        |
# +----------------------+---------+------------+
#
# d67zTET_2IuVoWcUU0aWaQ
# 1
# 46
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |igaoaFNkX7ieMuyUBg0u5w|Leang    |2000        |
# +----------------------+---------+------------+
#
# igaoaFNkX7ieMuyUBg0u5w
# 1
# 47
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |djxnI8Ux8ZYQJhiOQkrRhA|Abby     |1992        |
# +----------------------+---------+------------+
#
# djxnI8Ux8ZYQJhiOQkrRhA
# 1
# 48
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |6EHbIv5w2I4XbXs3dG_D1Q|David    |1956        |
# +----------------------+---------+------------+
#
# 6EHbIv5w2I4XbXs3dG_D1Q
# 1
# 49
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |EDBTE8HMO-iN5hAi9B382A|Cindy    |1924        |
# +----------------------+---------+------------+
#
# EDBTE8HMO-iN5hAi9B382A
# 1
# 50
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |MurRkRS5aYaa1IfaRY20_Q|Denis    |1924        |
# +----------------------+---------+------------+
#
# MurRkRS5aYaa1IfaRY20_Q
# 1
# 51
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |yh8_9Ix1wp9dekvyOZbilQ|Christina|1888        |
# +----------------------+---------+------------+
#
# yh8_9Ix1wp9dekvyOZbilQ
# 1
# 52
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |pou3BbKsIozfH50rxmnMew|Brett    |1871        |
# +----------------------+---------+------------+
#
# pou3BbKsIozfH50rxmnMew
# 1
# 53
# +----------------------+----------+------------+
# |user_id               |user_name |review_count|
# +----------------------+----------+------------+
# |kZJWAY828P8QZTqVYzhTCg|Fancypants|1852        |
# +----------------------+----------+------------+
#
# kZJWAY828P8QZTqVYzhTCg
# 1
# 54
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |IU86PZPgTDCFwJEuAg2j7g|Danny    |1822        |
# +----------------------+---------+------------+
#
# IU86PZPgTDCFwJEuAg2j7g
# 1
# 55
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |YRcaNlwQ6XXPFDXWtuMGdA|Chris    |1821        |
# +----------------------+---------+------------+
#
# YRcaNlwQ6XXPFDXWtuMGdA
# 1
# 56
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |j5ezF5mEGpnDwdTmAHci7Q|Albert   |1801        |
# +----------------------+---------+------------+
#
# j5ezF5mEGpnDwdTmAHci7Q
# 1
# 57
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |d8KR5c1ievS0C53h4fhEeQ|Kevin    |1772        |
# +----------------------+---------+------------+
#
# d8KR5c1ievS0C53h4fhEeQ
# 1
# 58
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |YbZg36FoMgkKcTEPae5siA|Amy      |1755        |
# +----------------------+---------+------------+
#
# YbZg36FoMgkKcTEPae5siA
# 1
# 59
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |3lUkFxUQKeMUYH7-z_kmjg|Angela   |1743        |
# +----------------------+---------+------------+
#
# 3lUkFxUQKeMUYH7-z_kmjg
# 1
# 60
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |lCmvpQfFpdxhbWVM59eUCg|Jocelyn  |1710        |
# +----------------------+---------+------------+
#
# lCmvpQfFpdxhbWVM59eUCg
# 1
# 61
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |GcdYgbaF75vj7RO6EZhPOQ|Kathleen |1700        |
# +----------------------+---------+------------+
#
# GcdYgbaF75vj7RO6EZhPOQ
# 1
# 62
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |ouODopBKF3AqfCkuQEnrDg|Danan    |1688        |
# +----------------------+---------+------------+
#
# ouODopBKF3AqfCkuQEnrDg
# 1
# 63
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |lvGlIBv4xkHiQBnNOuRYZQ|Jonathan |1687        |
# +----------------------+---------+------------+
#
# lvGlIBv4xkHiQBnNOuRYZQ
# 1
# 64
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |dHxvSPU6PZqX1LQRXajGDQ|Kimberly |1659        |
# +----------------------+---------+------------+
#
# dHxvSPU6PZqX1LQRXajGDQ
# 1
# 65
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |-3s52C4zL_DHRK0ULG6qtg|Sara     |1657        |
# +----------------------+---------+------------+
#
# -3s52C4zL_DHRK0ULG6qtg
# 1
# 66
# +----------------------+-----------+------------+
# |user_id               |user_name  |review_count|
# +----------------------+-----------+------------+
# |v-HcprOKPC1_F5_15t4JDw|Christopher|1646        |
# +----------------------+-----------+------------+
#
# v-HcprOKPC1_F5_15t4JDw
# 1
# 67
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |tlY0QMQDyfjQAEwHnzvFnw|Ken      |1640        |
# +----------------------+---------+------------+
#
# tlY0QMQDyfjQAEwHnzvFnw
# 1
# 68
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |yrWJ4YZWvFj_NDOvTRaAqA|Jessie   |1631        |
# +----------------------+---------+------------+
#
# yrWJ4YZWvFj_NDOvTRaAqA
# 1
# 69
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |0G-QF457q_0Z_jKqh6xWiA|Joi      |1623        |
# +----------------------+---------+------------+
#
# 0G-QF457q_0Z_jKqh6xWiA
# 1
# 70
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |d_-ypwVYiP-DswClkAg8Iw|Anne     |1611        |
# +----------------------+---------+------------+
#
# d_-ypwVYiP-DswClkAg8Iw
# 1
# 71
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |864nL0po2ldN8TPgbSiwOQ|Walter   |1606        |
# +----------------------+---------+------------+
#
# 864nL0po2ldN8TPgbSiwOQ
# 1
# 72
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |Vkj42md-5O3VoOD9pBg6Sw|Rick     |1605        |
# +----------------------+---------+------------+
#
# Vkj42md-5O3VoOD9pBg6Sw
# 1
# 73
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |Ctrp5IoEKHkixDSIyYHDpw|Nick     |1592        |
# +----------------------+---------+------------+
#
# Ctrp5IoEKHkixDSIyYHDpw
# 1
# 74
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |i-DWCn1Xk5-exHi0mBDO1g|Esther   |1589        |
# +----------------------+---------+------------+
#
# i-DWCn1Xk5-exHi0mBDO1g
# 1
# 75
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |SAfNyiLVgPZzp_aGpXnfwg|Chris    |1569        |
# +----------------------+---------+------------+
#
# SAfNyiLVgPZzp_aGpXnfwg
# 1
# 76
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |mDBAmEsyxuVTTT70dK-dqA|Elsie    |1568        |
# +----------------------+---------+------------+
#
# mDBAmEsyxuVTTT70dK-dqA
# 1
# 77
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |V5Th21KjUiYLJQyV-vGtpg|Ben H    |1556        |
# +----------------------+---------+------------+
#
# V5Th21KjUiYLJQyV-vGtpg
# 1
# 78
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |5aCEquYmXUIsWmpUp1gqxA|Kathleen |1550        |
# +----------------------+---------+------------+
#
# 5aCEquYmXUIsWmpUp1gqxA
# 1
# 79
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |XkLK2iBsgqF6mWwDfRgqqQ|Seong    |1526        |
# +----------------------+---------+------------+
#
# XkLK2iBsgqF6mWwDfRgqqQ
# 1
# 80
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |9U30DANobkrn3Zlu6T9p6Q|Jeff     |1525        |
# +----------------------+---------+------------+
#
# 9U30DANobkrn3Zlu6T9p6Q
# 1
# 81
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |qlC607Cyp0Mj91vDFvkp3Q|Nicole   |1508        |
# +----------------------+---------+------------+
#
# qlC607Cyp0Mj91vDFvkp3Q
# 1
# 82
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |swmrfBnaqU0nyJ3pFBfNgQ|Ry       |1505        |
# +----------------------+---------+------------+
#
# swmrfBnaqU0nyJ3pFBfNgQ
# 1
# 83
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |TmljCl6px9_1D-V1dEUR-w|Alf      |1499        |
# +----------------------+---------+------------+
#
# TmljCl6px9_1D-V1dEUR-w
# 1
# 84
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |jwtTBTYuL8249q26lmJH6A|Jessica  |1495        |
# +----------------------+---------+------------+
#
# jwtTBTYuL8249q26lmJH6A
# 1
# 85
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |7KVpIdVSWCzI5F7TGxQawA|Natasha  |1491        |
# +----------------------+---------+------------+
#
# 7KVpIdVSWCzI5F7TGxQawA
# 1
# 86
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |Mu6wz7_d6OBgRqkl4_NaXw|Kathleen |1485        |
# +----------------------+---------+------------+
#
# Mu6wz7_d6OBgRqkl4_NaXw
# 1
# 87
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |ncIHRw4Vx3Wh9mZhLZxB7g|Mindy    |1485        |
# +----------------------+---------+------------+
#
# ncIHRw4Vx3Wh9mZhLZxB7g
# 1
# 88
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |tXhscxwFTd-ayLTdPx_2yA|Jonah    |1470        |
# +----------------------+---------+------------+
#
# tXhscxwFTd-ayLTdPx_2yA
# 1
# 89
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |vx6BAchvzvetqHOOe3-sQg|J        |1470        |
# +----------------------+---------+------------+
#
# vx6BAchvzvetqHOOe3-sQg
# 1
# 90
# +----------------------+-------------+------------+
# |user_id               |user_name    |review_count|
# +----------------------+-------------+------------+
# |SDytcPY5fiuuDbTkPE8GyA|Pinky And The|1468        |
# +----------------------+-------------+------------+
#
# SDytcPY5fiuuDbTkPE8GyA
# 1
# 91
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |fr1Hz2acAb3OaL3l6DyKNg|Boon     |1468        |
# +----------------------+---------+------------+
#
# fr1Hz2acAb3OaL3l6DyKNg
# 1
# 92
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |MnYfi2DODiZkLIwJFuwB2g|Bill     |1465        |
# +----------------------+---------+------------+
#
# MnYfi2DODiZkLIwJFuwB2g
# 1
# 93
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |ntJ0mR5D4JqJOzsYZV-cxw|Virginia |1444        |
# +----------------------+---------+------------+
#
# ntJ0mR5D4JqJOzsYZV-cxw
# 1
# 94
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |pRfWy61wU9e1nrCVrOEWLA|Richard  |1434        |
# +----------------------+---------+------------+
#
# pRfWy61wU9e1nrCVrOEWLA
# 1
# 95
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |9GhiQOLaM6ZGrrFG-SppwQ|Bryan    |1429        |
# +----------------------+---------+------------+
#
# 9GhiQOLaM6ZGrrFG-SppwQ
# 1
# 96
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |CJmtS1Uk1KSsY2MWol_E7g|Asuka    |1397        |
# +----------------------+---------+------------+
#
# CJmtS1Uk1KSsY2MWol_E7g
# 1
# 97
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |dsX3MiQiTy3OVI8MKn0I4w|Andy     |1385        |
# +----------------------+---------+------------+
#
# dsX3MiQiTy3OVI8MKn0I4w
# 1
# 98
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |LhFzr2vZDEc2KNHxuiHtIw|Cat      |1382        |
# +----------------------+---------+------------+
#
# LhFzr2vZDEc2KNHxuiHtIw
# 1
# 99
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |opPpHVIp8SKHMJg3_y5Lew|Mike     |1381        |
# +----------------------+---------+------------+
#
# opPpHVIp8SKHMJg3_y5Lew
# 1
# 100
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |nx5-LzxIVXlQrKpWL_3PVQ|Mary     |1379        |
# +----------------------+---------+------------+
#
# nx5-LzxIVXlQrKpWL_3PVQ
# 1
# 101
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |XiFzYeOUdkL1HxVFlPsHSA|Alan     |1358        |
# +----------------------+---------+------------+
#
# XiFzYeOUdkL1HxVFlPsHSA
# 1
# 102
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |p6nBKyT9Y_pFJ1WxVEowwA|Andrew   |1352        |
# +----------------------+---------+------------+
#
# p6nBKyT9Y_pFJ1WxVEowwA
# 1
# 103
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |XKvbfNylF6Yq8hpwqaZrhA|Mihir    |1338        |
# +----------------------+---------+------------+
#
# XKvbfNylF6Yq8hpwqaZrhA
# 1
# 104
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |RmXIjppHNtVveguN10iO1g|Kevin    |1336        |
# +----------------------+---------+------------+
#
# RmXIjppHNtVveguN10iO1g
# 1
# 105
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |Rvn-Ymc8_9z4vbcm2ZwenQ|Ryna     |1329        |
# +----------------------+---------+------------+
#
# Rvn-Ymc8_9z4vbcm2ZwenQ
# 1
# 106
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |rLCbMQmIuWnlI-IhIj51kQ|Ryan     |1319        |
# +----------------------+---------+------------+
#
# rLCbMQmIuWnlI-IhIj51kQ
# 1
# 107
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |kLm3B6LeboEZWX_4otpILA|Izzat    |1312        |
# +----------------------+---------+------------+
#
# kLm3B6LeboEZWX_4otpILA
# 1
# 108
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |kxj7TPtJY2zbEjGV0PYfAA|Jenna    |1311        |
# +----------------------+---------+------------+
#
# kxj7TPtJY2zbEjGV0PYfAA
# 1
# 109
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |3KK7L2Q6NMfJA1Ky4Ntmdg|Ivy      |1308        |
# +----------------------+---------+------------+
#
# 3KK7L2Q6NMfJA1Ky4Ntmdg
# 1
# 110
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |mgytZAasaiBf-END4aZD9w|Cat      |1304        |
# +----------------------+---------+------------+
#
# mgytZAasaiBf-END4aZD9w
# 1
# 111
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |41kMyI1BfOTyIIAenUSaTQ|D'Arcy   |1303        |
# +----------------------+---------+------------+
#
# 41kMyI1BfOTyIIAenUSaTQ
# 1
# 112
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |oCYxjlqjpnW5WJAo6HNR0A|Alison   |1298        |
# +----------------------+---------+------------+
#
# oCYxjlqjpnW5WJAo6HNR0A
# 1
# 113
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |8xev0Avovx_jp7LEw8JqvA|Joolie   |1296        |
# +----------------------+---------+------------+
#
# 8xev0Avovx_jp7LEw8JqvA
# 1
# 114
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |8c3XuWaEQwzbV9AtiXB8mw|Tunaidi  |1294        |
# +----------------------+---------+------------+
#
# 8c3XuWaEQwzbV9AtiXB8mw
# 1
# 115
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |NXw0bCLF5ZtFMfhcj7CFSw|Tom      |1293        |
# +----------------------+---------+------------+
#
# NXw0bCLF5ZtFMfhcj7CFSw
# 1
# 116
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |4ZfcCa4m5RWvO4EFzfYm1A|Eli      |1293        |
# +----------------------+---------+------------+
#
# 4ZfcCa4m5RWvO4EFzfYm1A
# 1
# 117
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |SqVUNVeYJblyoUz4e-Fiqw|Joseph   |1290        |
# +----------------------+---------+------------+
#
# SqVUNVeYJblyoUz4e-Fiqw
# 1
# 118
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |ep8NBpLx5cfwy2CaE7cG4A|Helen    |1290        |
# +----------------------+---------+------------+
#
# ep8NBpLx5cfwy2CaE7cG4A
# 1
# 119
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |p4-tNsuQB6O11lp77KZKJg|H        |1289        |
# +----------------------+---------+------------+
#
# p4-tNsuQB6O11lp77KZKJg
# 1
# 120
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |jveIBHpWOfZFv24luiDjPA|David    |1286        |
# +----------------------+---------+------------+
#
# jveIBHpWOfZFv24luiDjPA
# 1
# 121
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |HXwc6YOOq6hcZl0ovFeHiQ|Charles  |1286        |
# +----------------------+---------+------------+
#
# HXwc6YOOq6hcZl0ovFeHiQ
# 1
# 122
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |APoAugdz6nscL4HjF4Oryg|Allene   |1268        |
# +----------------------+---------+------------+
#
# APoAugdz6nscL4HjF4Oryg
# 1
# 123
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |Lb37hatAjI3fgHEh2lMNEw|Josh     |1265        |
# +----------------------+---------+------------+
#
# Lb37hatAjI3fgHEh2lMNEw
# 1
# 124
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |Qjrn5UsK2HBZxx40HYA1iQ|Holly    |1256        |
# +----------------------+---------+------------+
#
# Qjrn5UsK2HBZxx40HYA1iQ
# 1
# 125
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |rQLEfpfSjVK-3dBmIMKZDA|Luke     |1254        |
# +----------------------+---------+------------+
#
# rQLEfpfSjVK-3dBmIMKZDA
# 1
# 126
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |r9Wii37p0kEDIUt2e2_LqQ|Randy    |1252        |
# +----------------------+---------+------------+
#
# r9Wii37p0kEDIUt2e2_LqQ
# 1
# 127
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |wo632pzj23-Di2RakSugjQ|Jeff     |1248        |
# +----------------------+---------+------------+
#
# wo632pzj23-Di2RakSugjQ
# 1
# 128
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |NNL1zLTP2J_SOputgoPYeQ|Alex     |1244        |
# +----------------------+---------+------------+
#
# NNL1zLTP2J_SOputgoPYeQ
# 1
# 129
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |ncAOj5Xz-XS6bpSnTWp3tQ|Austin   |1243        |
# +----------------------+---------+------------+
#
# ncAOj5Xz-XS6bpSnTWp3tQ
# 1
# 130
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |TAzGPFt9x99JCYWtDmZDWg|Derrick  |1242        |
# +----------------------+---------+------------+
#
# TAzGPFt9x99JCYWtDmZDWg
# 1
# 131
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |d4vqfqDzNFvYppXMPjJrow|Tom      |1235        |
# +----------------------+---------+------------+
#
# d4vqfqDzNFvYppXMPjJrow
# 1
# 132
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |ic-tyi1jElL_umxZVh8KNA|Owen     |1234        |
# +----------------------+---------+------------+
#
# ic-tyi1jElL_umxZVh8KNA
# 1
# 133
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |9EeEpkZg5jV18N_KvrcT6g|Lauren   |1227        |
# +----------------------+---------+------------+
#
# 9EeEpkZg5jV18N_KvrcT6g
# 1
# 134
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |w7RP1MZad3YO7Vjgp3s3Dg|Claudine |1225        |
# +----------------------+---------+------------+
#
# w7RP1MZad3YO7Vjgp3s3Dg
# 1
# 135
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |bs_FiiqQNyUg6Fh_WqyLyQ|Brandon  |1224        |
# +----------------------+---------+------------+
#
# bs_FiiqQNyUg6Fh_WqyLyQ
# 1
# 136
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |58yXn5Y4409kc9q88YwU6w|Kimberly |1220        |
# +----------------------+---------+------------+
#
# 58yXn5Y4409kc9q88YwU6w
# 1
# 137
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |q_QQ5kBBwlCcbL1s4NVK3g|Jane     |1213        |
# +----------------------+---------+------------+
#
# q_QQ5kBBwlCcbL1s4NVK3g
# 1
# 138
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |dt9IHwfuZs9D9LOH7gjNew|P        |1208        |
# +----------------------+---------+------------+
#
# dt9IHwfuZs9D9LOH7gjNew
# 1
# 139
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |WeVkkF5L39888IPPlRhNpg|Kris     |1207        |
# +----------------------+---------+------------+
#
# WeVkkF5L39888IPPlRhNpg
# 1
# 140
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |MoCD_-Eh_j6-dI0V57hG9g|Amy      |1200        |
# +----------------------+---------+------------+
#
# MoCD_-Eh_j6-dI0V57hG9g
# 1
# 141
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |H5d_nFqzwrREE-YduK2ABg|Julie    |1200        |
# +----------------------+---------+------------+
#
# H5d_nFqzwrREE-YduK2ABg
# 1
# 142
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |oZ4zwTAR2C9kGUL2aCGccQ|Bert     |1194        |
# +----------------------+---------+------------+
#
# oZ4zwTAR2C9kGUL2aCGccQ
# 1
# 143
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |Wc5L6iuvSNF5WGBlqIO8nw|Risa     |1191        |
# +----------------------+---------+------------+
#
# Wc5L6iuvSNF5WGBlqIO8nw
# 1
# 144
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |7bwDw99gKkuxr-zBtzqvCg|Jake     |1183        |
# +----------------------+---------+------------+
#
# 7bwDw99gKkuxr-zBtzqvCg
# 1
# 145
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |PdpWp_j67Nfr_oQF-4yKUw|Kenneth  |1183        |
# +----------------------+---------+------------+
#
# PdpWp_j67Nfr_oQF-4yKUw
# 1
# 146
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |0BBUmH7Krcax1RZgbH4fSA|Laura C  |1177        |
# +----------------------+---------+------------+
#
# 0BBUmH7Krcax1RZgbH4fSA
# 1
# 147
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |OnagJ2dnPjfRRT4a_CgKCw|Mimi     |1176        |
# +----------------------+---------+------------+
#
# OnagJ2dnPjfRRT4a_CgKCw
# 1
# 148
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |CMW-yrCQrRnhAg0yvRajvA|Philip   |1174        |
# +----------------------+---------+------------+
#
# CMW-yrCQrRnhAg0yvRajvA
# 1
# 149
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |yaBIVHDxaUBN2YHQ8-YiuQ|Meredith |1173        |
# +----------------------+---------+------------+
#
# yaBIVHDxaUBN2YHQ8-YiuQ
# 1
# 150
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |Y0DSxhhChQwzoQsLeDuvRw|Tim      |1169        |
# +----------------------+---------+------------+
#
# Y0DSxhhChQwzoQsLeDuvRw
# 1
# 151
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |-vjSUjoYYROCHImyLenDNA|Audrey   |1168        |
# +----------------------+---------+------------+
#
# -vjSUjoYYROCHImyLenDNA
# 1
# 152
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |yeGIAyHixJrIe-zmXiePWQ|Adam     |1161        |
# +----------------------+---------+------------+
#
# yeGIAyHixJrIe-zmXiePWQ
# 1
# 153
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |8zXgNCkusOHMwh5Tj_8yCQ|Wing     |1161        |
# +----------------------+---------+------------+
#
# 8zXgNCkusOHMwh5Tj_8yCQ
# 1
# 154
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |4m9NXICYBC5i9t4aTt-I6w|Jason    |1159        |
# +----------------------+---------+------------+
#
# 4m9NXICYBC5i9t4aTt-I6w
# 1
# 155
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |y_jl-bErj1mnb4KF04F74Q|Vicki    |1159        |
# +----------------------+---------+------------+
#
# y_jl-bErj1mnb4KF04F74Q
# 1
# 156
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |bVthsfeUU3Bd5AeJLqKT-w|Flora    |1157        |
# +----------------------+---------+------------+
#
# bVthsfeUU3Bd5AeJLqKT-w
# 1
# 157
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |aIzN19RssPWSw9nDCPXU3A|Jonathan |1154        |
# +----------------------+---------+------------+
#
# aIzN19RssPWSw9nDCPXU3A
# 1
# 158
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |Q9mA60HnY87C1TW5kjAZ6Q|Evelyn   |1140        |
# +----------------------+---------+------------+
#
# Q9mA60HnY87C1TW5kjAZ6Q
# 1
# 159
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |hntJTn1Ev6TXfusbvTdutw|Lucky    |1139        |
# +----------------------+---------+------------+
#
# hntJTn1Ev6TXfusbvTdutw
# 1
# 160
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |cYjzLu3fm-VbtjRMCuhK6Q|Jennifer |1138        |
# +----------------------+---------+------------+
#
# cYjzLu3fm-VbtjRMCuhK6Q
# 1
# 161
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |wjQv92px4xHjbBoATkOTUw|Jennifer |1136        |
# +----------------------+---------+------------+
#
# wjQv92px4xHjbBoATkOTUw
# 1
# 162
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |tSdz6ZkR0psn41cCaaTlYw|Alyx     |1136        |
# +----------------------+---------+------------+
#
# tSdz6ZkR0psn41cCaaTlYw
# 1
# 163
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |Y8UTUzqG-JJGKGC0Fv643w|Simon    |1136        |
# +----------------------+---------+------------+
#
# Y8UTUzqG-JJGKGC0Fv643w
# 1
# 164
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |U5YQX_vMl_xQy8EQDqlNQQ|Stephanie|1130        |
# +----------------------+---------+------------+
#
# U5YQX_vMl_xQy8EQDqlNQQ
# 1
# 165
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |h1KzT38UnfzR7maSi7oVUw|Andrew   |1128        |
# +----------------------+---------+------------+
#
# h1KzT38UnfzR7maSi7oVUw
# 1
# 166
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |uL-3W26bfqP54fENoj7b8g|Jeruen   |1126        |
# +----------------------+---------+------------+
#
# uL-3W26bfqP54fENoj7b8g
# 1
# 167
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |duymKKwUruH8GwbvcaFd0w|Gene     |1124        |
# +----------------------+---------+------------+
#
# duymKKwUruH8GwbvcaFd0w
# 1
# 168
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |F6MPrQ5oxQL2Wq1v5ENDzA|Robert   |1122        |
# +----------------------+---------+------------+
#
# F6MPrQ5oxQL2Wq1v5ENDzA
# 1
# 169
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |8Kjf1ulh1ox5RiO42UI4IQ|John     |1117        |
# +----------------------+---------+------------+
#
# 8Kjf1ulh1ox5RiO42UI4IQ
# 1
# 170
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |Wx7cbLDqYEL3_aVZwh82Ww|Sapna    |1116        |
# +----------------------+---------+------------+
#
# Wx7cbLDqYEL3_aVZwh82Ww
# 1
# 171
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |O3pSxv1SyHpY4qi4Q16KzA|Teena    |1116        |
# +----------------------+---------+------------+
#
# O3pSxv1SyHpY4qi4Q16KzA
# 1
# 172
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |0XOVMcvzlfKRPqjbmCN5pQ|Robin    |1095        |
# +----------------------+---------+------------+
#
# 0XOVMcvzlfKRPqjbmCN5pQ
# 1
# 173
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |T0HWgeviH7722ZJpWFrB4Q|Nina     |1092        |
# +----------------------+---------+------------+
#
# T0HWgeviH7722ZJpWFrB4Q
# 1
# 174
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |50wPDE_Gk936RYV7i4FJhw|Haroun   |1092        |
# +----------------------+---------+------------+
#
# 50wPDE_Gk936RYV7i4FJhw
# 1
# 175
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |kiKyT3FN1H3d3jSTU5I3zg|Hana     |1088        |
# +----------------------+---------+------------+
#
# kiKyT3FN1H3d3jSTU5I3zg
# 1
# 176
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |R-c5M0iJkMxxTxIqTQQZ8w|Yo       |1088        |
# +----------------------+---------+------------+
#
# R-c5M0iJkMxxTxIqTQQZ8w
# 1
# 177
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |65yB0ydGXOZ_-T6J_GbKfw|Lambert  |1087        |
# +----------------------+---------+------------+
#
# 65yB0ydGXOZ_-T6J_GbKfw
# 1
# 178
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |4wp4XI9AxKNqJima-xahlg|Rachel   |1087        |
# +----------------------+---------+------------+
#
# 4wp4XI9AxKNqJima-xahlg
# 1
# 179
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |jnB_saJqNfOmVoCWquhAzg|Bilal    |1087        |
# +----------------------+---------+------------+
#
# jnB_saJqNfOmVoCWquhAzg
# 1
# 180
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |Wu0yySWcHQ5tZ_59HNiamg|WaYnE    |1083        |
# +----------------------+---------+------------+
#
# Wu0yySWcHQ5tZ_59HNiamg
# 1
# 181
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |MbC0xPzIdGkFMCpPb8yWDA|Hideki   |1079        |
# +----------------------+---------+------------+
#
# MbC0xPzIdGkFMCpPb8yWDA
# 1
# 182
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |4OgPAPL0zCXmdmV5_oe3vQ|Julie    |1078        |
# +----------------------+---------+------------+
#
# 4OgPAPL0zCXmdmV5_oe3vQ
# 1
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-61-c5ea7d10526c> in <module>()
#       4
#       5     sim_users = getUserDetails(getSimilarUsers([uid], all_user_vecs, 10))
# ----> 6     sim_users_pd = sim_users.select('input_user_id', 'a.user_id', 'user_name', 'score','review_count').toPandas()
#       7     sim_users_all = pd.concat([sim_users_all, sim_users_pd])
#       8     sim_users_all = sim_users_all.drop_duplicates()
#
# /usr/local/Cellar/apache-spark/2.3.1/libexec/python/pyspark/sql/dataframe.py in toPandas(self)
#    1966                 raise RuntimeError("%s\n%s" % (_exception_message(e), msg))
#    1967         else:
# -> 1968             pdf = pd.DataFrame.from_records(self.collect(), columns=self.columns)
#    1969
#    1970             dtype = {}
#
# /usr/local/Cellar/apache-spark/2.3.1/libexec/python/pyspark/sql/dataframe.py in collect(self)
#     464         """
#     465         with SCCallSiteSync(self._sc) as css:
# --> 466             sock_info = self._jdf.collectToPython()
#     467         return list(_load_from_socket(sock_info, BatchedSerializer(PickleSerializer())))
#     468
#
# /anaconda3/lib/python3.6/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# /usr/local/Cellar/apache-spark/2.3.1/libexec/python/pyspark/sql/utils.py in deco(*a, **kw)
#      61     def deco(*a, **kw):
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#      65             s = e.java_exception.toString()
#
# /anaconda3/lib/python3.6/site-packages/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     326                 raise Py4JJavaError(
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#     330                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling o42506.collectToPython.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 7 in stage 3136.0 failed 1 times, most recent failure: Lost task 7.0 in stage 3136.0 (TID 99908, localhost, executor driver): java.lang.OutOfMemoryError: GC overhead limit exceeded
# 	at net.razorvine.pickle.PickleUtils.readbytes(PickleUtils.java:54)
# 	at net.razorvine.pickle.Unpickler.load_long_binput(Unpickler.java:655)
# 	at net.razorvine.pickle.Unpickler.dispatch(Unpickler.java:236)
# 	at net.razorvine.pickle.Unpickler.load(Unpickler.java:99)
# 	at net.razorvine.pickle.Unpickler.loads(Unpickler.java:112)
# 	at org.apache.spark.api.python.SerDeUtil$$anonfun$pythonToJava$1$$anonfun$apply$1.apply(SerDeUtil.scala:188)
# 	at org.apache.spark.api.python.SerDeUtil$$anonfun$pythonToJava$1$$anonfun$apply$1.apply(SerDeUtil.scala:187)
# 	at scala.collection.Iterator$$anon$12.nextCur(Iterator.scala:434)
# 	at scala.collection.Iterator$$anon$12.hasNext(Iterator.scala:440)
# 	at scala.collection.Iterator$$anon$11.hasNext(Iterator.scala:408)
# 	at scala.collection.Iterator$$anon$11.hasNext(Iterator.scala:408)
# 	at scala.collection.Iterator$$anon$11.hasNext(Iterator.scala:408)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage4.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenExec$$anonfun$10$$anon$1.hasNext(WholeStageCodegenExec.scala:614)
# 	at scala.collection.Iterator$$anon$11.hasNext(Iterator.scala:408)
# 	at scala.collection.convert.Wrappers$IteratorWrapper.hasNext(Wrappers.scala:30)
# 	at org.spark_project.guava.collect.Ordering.leastOf(Ordering.java:670)
# 	at org.apache.spark.util.collection.Utils$.takeOrdered(Utils.scala:37)
# 	at org.apache.spark.sql.execution.TakeOrderedAndProjectExec$$anonfun$5.apply(limit.scala:150)
# 	at org.apache.spark.sql.execution.TakeOrderedAndProjectExec$$anonfun$5.apply(limit.scala:149)
# 	at org.apache.spark.rdd.RDD$$anonfun$mapPartitions$1$$anonfun$apply$23.apply(RDD.scala:800)
# 	at org.apache.spark.rdd.RDD$$anonfun$mapPartitions$1$$anonfun$apply$23.apply(RDD.scala:800)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:324)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:288)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:324)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:288)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:96)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:53)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:109)
#
# Driver stacktrace:
# 	at org.apache.spark.scheduler.DAGScheduler.org$apache$spark$scheduler$DAGScheduler$$failJobAndIndependentStages(DAGScheduler.scala:1602)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$abortStage$1.apply(DAGScheduler.scala:1590)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$abortStage$1.apply(DAGScheduler.scala:1589)
# 	at scala.collection.mutable.ResizableArray$class.foreach(ResizableArray.scala:59)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:48)
# 	at org.apache.spark.scheduler.DAGScheduler.abortStage(DAGScheduler.scala:1589)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$handleTaskSetFailed$1.apply(DAGScheduler.scala:831)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$handleTaskSetFailed$1.apply(DAGScheduler.scala:831)
# 	at scala.Option.foreach(Option.scala:257)
# 	at org.apache.spark.scheduler.DAGScheduler.handleTaskSetFailed(DAGScheduler.scala:831)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.doOnReceive(DAGScheduler.scala:1823)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:1772)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:1761)
# 	at org.apache.spark.util.EventLoop$$anon$1.run(EventLoop.scala:48)
# 	at org.apache.spark.scheduler.DAGScheduler.runJob(DAGScheduler.scala:642)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:2034)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:2055)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:2074)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:2099)
# 	at org.apache.spark.rdd.RDD$$anonfun$collect$1.apply(RDD.scala:939)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:112)
# 	at org.apache.spark.rdd.RDD.withScope(RDD.scala:363)
# 	at org.apache.spark.rdd.RDD.collect(RDD.scala:938)
# 	at org.apache.spark.sql.execution.SparkPlan.executeCollect(SparkPlan.scala:297)
# 	at org.apache.spark.sql.Dataset$$anonfun$collectToPython$1.apply(Dataset.scala:3195)
# 	at org.apache.spark.sql.Dataset$$anonfun$collectToPython$1.apply(Dataset.scala:3192)
# 	at org.apache.spark.sql.Dataset$$anonfun$52.apply(Dataset.scala:3254)
# 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId(SQLExecution.scala:77)
# 	at org.apache.spark.sql.Dataset.withAction(Dataset.scala:3253)
# 	at org.apache.spark.sql.Dataset.collectToPython(Dataset.scala:3192)
# 	at sun.reflect.GeneratedMethodAccessor118.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:748)
# Caused by: java.lang.OutOfMemoryError: GC overhead limit exceeded
# 	at net.razorvine.pickle.PickleUtils.readbytes(PickleUtils.java:54)
# 	at net.razorvine.pickle.Unpickler.load_long_binput(Unpickler.java:655)
# 	at net.razorvine.pickle.Unpickler.dispatch(Unpickler.java:236)
# 	at net.razorvine.pickle.Unpickler.load(Unpickler.java:99)
# 	at net.razorvine.pickle.Unpickler.loads(Unpickler.java:112)
# 	at org.apache.spark.api.python.SerDeUtil$$anonfun$pythonToJava$1$$anonfun$apply$1.apply(SerDeUtil.scala:188)
# 	at org.apache.spark.api.python.SerDeUtil$$anonfun$pythonToJava$1$$anonfun$apply$1.apply(SerDeUtil.scala:187)
# 	at scala.collection.Iterator$$anon$12.nextCur(Iterator.scala:434)
# 	at scala.collection.Iterator$$anon$12.hasNext(Iterator.scala:440)
# 	at scala.collection.Iterator$$anon$11.hasNext(Iterator.scala:408)
# 	at scala.collection.Iterator$$anon$11.hasNext(Iterator.scala:408)
# 	at scala.collection.Iterator$$anon$11.hasNext(Iterator.scala:408)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage4.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenExec$$anonfun$10$$anon$1.hasNext(WholeStageCodegenExec.scala:614)
# 	at scala.collection.Iterator$$anon$11.hasNext(Iterator.scala:408)
# 	at scala.collection.convert.Wrappers$IteratorWrapper.hasNext(Wrappers.scala:30)
# 	at org.spark_project.guava.collect.Ordering.leastOf(Ordering.java:670)
# 	at org.apache.spark.util.collection.Utils$.takeOrdered(Utils.scala:37)
# 	at org.apache.spark.sql.execution.TakeOrderedAndProjectExec$$anonfun$5.apply(limit.scala:150)
# 	at org.apache.spark.sql.execution.TakeOrderedAndProjectExec$$anonfun$5.apply(limit.scala:149)
# 	at org.apache.spark.rdd.RDD$$anonfun$mapPartitions$1$$anonfun$apply$23.apply(RDD.scala:800)
# 	at org.apache.spark.rdd.RDD$$anonfun$mapPartitions$1$$anonfun$apply$23.apply(RDD.scala:800)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:324)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:288)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:324)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:288)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:96)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:53)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:109)
# ----------------------------------------
# Exception happened during processing of request from ('127.0.0.1', 61865)
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/socketserver.py", line 317, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/anaconda3/lib/python3.6/socketserver.py", line 348, in process_request
#     self.finish_request(request, client_address)
#   File "/anaconda3/lib/python3.6/socketserver.py", line 361, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/anaconda3/lib/python3.6/socketserver.py", line 696, in __init__
#     self.handle()
#   File "/usr/local/Cellar/apache-spark/2.3.1/libexec/python/pyspark/accumulators.py", line 235, in handle
#     num_updates = read_int(self.rfile)
#   File "/usr/local/Cellar/apache-spark/2.3.1/libexec/python/pyspark/serializers.py", line 685, in read_int
#     raise EOFError
# EOFError
# ----------------------------------------

# %%
merged_100 = pd.DataFrame(columns = ['business_id', 'stars_x', 'stars_y', 'text_x', 'text_y', 'date_x', 'date_y'])

for i in range(len(sim_users_all)):
    review_uid1 = review.loc[review['user_id'].isin([sim_users_all.input_user_id.iloc[i]])] 
    review_uid2 = review.loc[review['user_id'].isin([sim_users_all.user_id.iloc[i]])] 
    merged = pd.merge(review_uid1, review_uid2, how = 'inner', on = 'business_id')
    merged = merged[['user_id_x', 'user_id_y', 'business_id', 'stars_x', 'stars_y', 'text_x', 'text_y', 'date_x', 'date_y']]
    merged_100 = pd.concat([merged_100, merged])
    
with open("user_simil_business_ratings.txt", "wb") as fp:   #Pickling
    pickle.dump(merged_100, fp)

merged_100.to_csv("user_simil_business_ratings_500.csv")

# %%
# use this similarity matrix, recommend highly rated businesses from similar users
# high similarity can be seen, even if they have not reviewed a business in common.
# using similar model of users for businesses, can identify highly similar businesses
    # these businesses can be similar in ratings, category of business
