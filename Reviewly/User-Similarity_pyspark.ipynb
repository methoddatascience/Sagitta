# %%
from operator import add
from pyspark.ml.feature import RegexTokenizer, CountVectorizer
from pyspark.ml.feature import StopWordsRemover, VectorAssembler
from pyspark.ml.feature import Word2Vec, Word2VecModel
from pyspark.ml.feature import IDF
from pyspark.ml import Pipeline, PipelineModel

from pyspark.sql.functions import *
from pyspark.sql.types import *

from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession
#sc = SparkContext(gateway = jg.launch_gateway())

import folium
import html

import pandas as pd
import numpy as np

# %%
data_path = '/Volumes/Transcend/dataset/'
model_path = '/Volumes/Transcend/MDS_Yelp/model/'
outout_path = '/Volumes/Transcend/MDS_Yelp/output/'

# %%
sc = SparkContext()
#sc = SparkContext('local')
spark = SparkSession(sc)

# %%
business_df = spark.read.parquet(data_path + 'business-small.parquet')
business_df.printSchema()

# %%
user_df = spark.read.parquet(data_path + 'user-small.parquet')
user_df.printSchema()
# Out:
# root
#  |-- user_id: string (nullable = true)
#  |-- user_name: string (nullable = true)
#  |-- review_count: long (nullable = true)
#  |-- yelping_since: string (nullable = true)
#  |-- useful: long (nullable = true)
#  |-- funny: long (nullable = true)
#  |-- cool: long (nullable = true)
#  |-- fans: long (nullable = true)
#  |-- average_stars: double (nullable = true)

# %%
review_df = spark.read.parquet(data_path + 'review-small.parquet')
review_df.printSchema()
# Out:
# root
#  |-- review_id: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- business_id: string (nullable = true)
#  |-- stars: long (nullable = true)
#  |-- review_date: string (nullable = true)
#  |-- review_text: string (nullable = true)
#  |-- useful: long (nullable = true)
#  |-- funny: long (nullable = true)
#  |-- cool: long (nullable = true)

# %%
# create SQL view for later queries
review_df.createOrReplaceTempView("reviews")

# create review text dataframe
reviews_text = spark.sql("SELECT user_id, review_text FROM reviews")
reviews_text.show(3)
# Out:
# +--------------------+--------------------+
# |             user_id|         review_text|
# +--------------------+--------------------+
# |u0LXt3Uea_GidxRW1...|Who would have gu...|
# |u0LXt3Uea_GidxRW1...|Not bad!! Love th...|
# |u0LXt3Uea_GidxRW1...|This is currently...|
# +--------------------+--------------------+
# only showing top 3 rows

# %%
# concatenate all reviews per restuarant

reviews_text_rdd = reviews_text.rdd
reviews_by_user_rdd = reviews_text_rdd.map(tuple).reduceByKey(add)  
reviews_by_user_df = spark.createDataFrame(reviews_by_user_rdd)
reviews_by_user_df = reviews_by_user_df \
                            .withColumnRenamed('_1', 'user_id') \
                            .withColumnRenamed('_2', 'text')
reviews_by_user_df.count()
# Out:
# 73041

# %%
## Example of using Word2vec
from pyspark.ml.feature import Word2Vec

# Input data: Each row is a bag of words from a sentence or document.
documentDF = spark.createDataFrame([
    ("Hi I heard about Spark".split(" "), ),
    ("I wish Java could use case classes".split(" "), ),
    ("Logistic regression models are neat".split(" "), )
], ["text"])

# Learn a mapping from words to Vectors.
word2Vec = Word2Vec(vectorSize=3, minCount=0, inputCol="text", outputCol="result")
model = word2Vec.fit(documentDF)

result = model.transform(documentDF)
for row in result.collect():
    text, vector = row
    print("Text: [%s] => \nVector: %s\n" % (", ".join(text), str(vector)))
# Out:
# Text: [Hi, I, heard, about, Spark] =>
# Vector: [0.02326762331649661,0.008931299671530724,-0.06394885405898094]
#
# Text: [I, wish, Java, could, use, case, classes] =>
# Vector: [-0.009175857529044151,-0.024911361613443917,0.012272004171141555]
#
# Text: [Logistic, regression, models, are, neat] =>
# Vector: [-0.005160079896450043,-0.0005152661353349686,0.014656295813620091]

# %%
## https://spark.apache.org/docs/latest/api/python/pyspark.ml.html#pyspark.ml.feature.Word2Vec

## The minimum number of times a token must appear to be included in the word2vec model's vocabulary"

# %%
# %%time

# create text processing pipeline -- this a lengthy resource-intensive process
# Build the pipeline 
regexTokenizer = RegexTokenizer(gaps = False, pattern = '\w+', inputCol = 'text', outputCol = 'token')
stopWordsRemover = StopWordsRemover(inputCol = 'token', outputCol = 'nostopwrd')
countVectorizer = CountVectorizer(inputCol="nostopwrd", outputCol="rawFeature")
iDF = IDF(inputCol="rawFeature", outputCol="idf_vec")
word2Vec = Word2Vec(vectorSize = 100, minCount = 5, inputCol = 'nostopwrd', outputCol = 'word_vec', seed=123)
vectorAssembler = VectorAssembler(inputCols=['idf_vec', 'word_vec'], outputCol='comb_vec')
pipeline = Pipeline(stages=[regexTokenizer, stopWordsRemover, countVectorizer, iDF, word2Vec, vectorAssembler])

# fit the model
pipeline_mdl = pipeline.fit(reviews_by_user_df)

#save the pipeline model
pipeline_mdl.write().overwrite().save(model_path + 'pipe_txt')

# %%
# load the text transformation pipeline trained model
pipeline_mdl = PipelineModel.load(model_path + 'pipe_txt')

# %%
# transform the review data
reviews_by_user_trf_df = pipeline_mdl.transform(reviews_by_user_df)

# %%
# show the transformed review data
reviews_by_user_trf_df.select( 'text', 'nostopwrd', 'idf_vec', 'word_vec', 'comb_vec').show(10)
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+
# |                text|           nostopwrd|             idf_vec|            word_vec|            comb_vec|
# +--------------------+--------------------+--------------------+--------------------+--------------------+
# |A born and bred T...|[born, bred, toro...|(128365,[0,1,2,3,...|[-0.0298230579082...|(128465,[0,1,2,3,...|
# |I have never done...|[never, done, one...|(128365,[2,6,11,1...|[-0.0256846508636...|(128465,[2,6,11,1...|
# |What a find!  I'm...|[find, m, almost,...|(128365,[2,3,6,11...|[-0.0783052189961...|(128465,[2,3,6,11...|
# |Not impressed wit...|[impressed, place...|(128365,[0,1,2,3,...|[-0.0273270801487...|(128465,[0,1,2,3,...|
# |Very tight space....|[tight, space, fo...|(128365,[2,39,116...|[-0.0261619807634...|(128465,[2,39,116...|
# |While in Toronto ...|[toronto, last, w...|(128365,[0,1,2,3,...|[-0.0836421314076...|(128465,[0,1,2,3,...|
# |I loved the decor...|[loved, decor, re...|(128365,[0,1,3,5,...|[-0.0428024260223...|(128465,[0,1,3,5,...|
# |Amazing vermacell...|[amazing, vermace...|(128365,[0,2,4,5,...|[-0.1015487008305...|(128465,[0,2,4,5,...|
# |Uncle Tetsu's is ...|[uncle, tetsu, ho...|(128365,[0,1,2,4,...|[-0.0397153475544...|(128465,[0,1,2,4,...|
# |Love this place! ...|[love, place, eve...|(128365,[0,1,2,3,...|[0.00909978398385...|(128465,[0,1,2,3,...|
# +--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 10 rows

# %%
def CosineSim(vec1, vec2): 
    return np.dot(vec1, vec2) / np.sqrt(np.dot(vec1, vec1)) / np.sqrt(np.dot(vec2, vec2))

# %%
all_user_vecs = reviews_by_user_trf_df.select('user_id', 'word_vec').rdd.map(lambda x: (x[0], x[1])).collect()

# %% [raw]
# def toCSVLine(data):
#     return(','.join(str(d) for d in data))
#
# lines = rdd_odj.map(toCSVLine)
# lines.saveAsTextFile('rdd_file_to_csv.csv')

# %%
type(all_user_vecs)
# Out:
# list

# %%
all_user_vecs[0]
# user_id = 'nOTl4aPC4tKHK35T3bNauQ'
# DenseVector() - vector respresentation of all the reviews of User
# Out:
# ('BytRWk8X1OelSgwwfXd8Aw',
#  DenseVector([-0.0298, -0.0741, -0.0649, 0.0832, 0.0279, -0.0149, -0.0436, -0.0123, -0.0076, -0.0379, -0.0085, -0.0369, -0.0037, -0.0116, 0.0142, -0.0317, -0.0555, -0.0272, -0.0729, 0.0104, -0.0666, -0.0442, 0.0158, 0.0029, 0.0563, -0.0458, -0.0137, -0.0207, -0.0063, 0.0337, 0.0583, 0.0148, 0.0212, -0.0019, -0.031, -0.0436, 0.0617, 0.0352, -0.0151, -0.0433, -0.0319, -0.0212, -0.0246, 0.0944, 0.0214, -0.0364, -0.0363, 0.0447, 0.0029, 0.0008, 0.0107, -0.0229, -0.0219, -0.045, -0.0714, 0.0296, 0.0166, 0.0181, 0.0324, -0.0024, -0.0046, 0.0065, 0.0301, -0.049, -0.0385, 0.0413, 0.0566, 0.0437, -0.0322, 0.0902, -0.0098, -0.0056, 0.0242, 0.0346, 0.0133, -0.0412, -0.0373, 0.0083, -0.0207, 0.0461, -0.0175, -0.0269, 0.0018, -0.0071, -0.0001, 0.0023, 0.0449, 0.0108, 0.0087, 0.0074, 0.013, -0.0001, -0.0442, 0.0266, -0.0158, -0.0175, -0.0496, 0.0423, -0.0899, 0.034]))

# %%
def getSimilarUsers(b_ids, sim_user_limit=10):
    
    schema = StructType([   
                            StructField("user_id", StringType(), True)
                            ,StructField("score", IntegerType(), True)
                            ,StructField("input_user_id", StringType(), True)
                        ])
    
    similar_user_df = spark.createDataFrame([], schema)
    similar_user_df_all = spark.createDataFrame([], schema)
    
    for b_id in b_ids:
        
        input_vec = [(r[1]) for r in all_user_vecs if r[0] == b_id][0]
        
        similar_user_rdd = sc.parallelize((i[0], float(CosineSim(input_vec, i[1]))) for i in all_user_vecs)
        
        similar_user_df = spark.createDataFrame(similar_user_rdd) \
            .withColumnRenamed('_1', 'user_id') \
            .withColumnRenamed('_2', 'score') \
            .orderBy("score", ascending = False)
            
        similar_user_df = similar_user_df.dropna()    
        similar_user_df = similar_user_df.filter(col("user_id") != b_id).limit(sim_user_limit)
        similar_user_df = similar_user_df.withColumn('input_user_id', lit(b_id))
        
        similar_user_df = similar_user_df \
                                    .union(similar_user_df)
        
        similar_user_df_all = similar_user_df_all.union(similar_user_df)
    similar_user_df_all = similar_user_df_all.dropDuplicates()    
    return similar_user_df_all

# %%
def getUserDetails(in_bus):
    
    a = in_bus.alias("a")
    b = user_df.alias("b")
    
    return a.join(b, col("a.user_id") == col("b.user_id"), 'inner') \
             .select([col('a.'+xx) for xx in a.columns] + [col('b.user_id'), col('b.user_name'),col('b.review_count')])

# %%
# test with two restaurants

uids = ['nOTl4aPC4tKHK35T3bNauQ', 'QBac9-Ii6jR-yLsQ5MVTHg']

print('\ninput user details:')
user_df.select('user_id','user_name', 'review_count') \
    .filter(user_df.user_id.isin(uids) == True).show(truncate=False)
    
# get top 10 similar business
sim_users = getUserDetails(getSimilarUsers(uids))

print('Top 10 similar Users for each input restaurant are:"')
sim_users.select('input_user_id', 'a.user_id', 'user_name', 'score','review_count').toPandas()
# Out:
# input user details:
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |nOTl4aPC4tKHK35T3bNauQ|Katherine|148         |
# |QBac9-Ii6jR-yLsQ5MVTHg|Alex     |13          |
# +----------------------+---------+------------+
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in double_scalars
# Top 10 similar Users for each input restaurant are:"
#              input_user_id                 user_id user_name     score  \
# 0   QBac9-Ii6jR-yLsQ5MVTHg  J5Eb7LhJaOa20k0ppcOCOg      Alek  0.907664
# 1   nOTl4aPC4tKHK35T3bNauQ  ZBllYKrFzaI0I7v6Wl26Wg   Cecilia  0.963999
# 2   QBac9-Ii6jR-yLsQ5MVTHg  cNhHuEQMIpLH_qc9qGz67A       Jay  0.910774
# 3   QBac9-Ii6jR-yLsQ5MVTHg  _IR48ok0ZkPMWJ2PlRCk0A   Michael  0.907098
# 4   nOTl4aPC4tKHK35T3bNauQ  myrcQ3h2G04Gv-ANG_oqrg     Linda  0.971381
# 5   QBac9-Ii6jR-yLsQ5MVTHg  MpN81tQOL86GaFse-_tTRQ       Amy  0.913263
# 6   QBac9-Ii6jR-yLsQ5MVTHg  kw-YtOKPXrRB2a9wRZlmzQ     Jimmy  0.915453
# 7   nOTl4aPC4tKHK35T3bNauQ  uO1w3qNo21c1bVHHFTYW0w    Joanne  0.972255
# 8   QBac9-Ii6jR-yLsQ5MVTHg  g5W7s0n19gvT1Ujy_ITJog      Bria  0.907846
# 9   nOTl4aPC4tKHK35T3bNauQ  PGx4HvY5joEeqXzam6tO7A      Lisa  0.965808
# 10  QBac9-Ii6jR-yLsQ5MVTHg  bPUpO-bP6BmAGvSwPyDsng   Michael  0.905848
# 11  nOTl4aPC4tKHK35T3bNauQ  VVm-TFCpi9M1-k8ED0l1eA   Juliana  0.971013
# 12  QBac9-Ii6jR-yLsQ5MVTHg  xcBcIMVWEx1p7V8ACaeHpQ      Rick  0.918668
# 13  nOTl4aPC4tKHK35T3bNauQ  yL60onlTh1BmJKVLli_K3g  Danielle  0.964604
# 14  nOTl4aPC4tKHK35T3bNauQ  vJGLEHyhCs9V-5fAe-xx3w      Lisa  0.968622
# 15  nOTl4aPC4tKHK35T3bNauQ  v1nRL_f2EQs7fjh_m0TdQQ     Bryan  0.969187
# 16  nOTl4aPC4tKHK35T3bNauQ  n4usc2DF4pd9fdi2wLDloQ    Lidiya  0.964592
# 17  nOTl4aPC4tKHK35T3bNauQ  USUw_VT31ygQ9JkEc6nPsg        NJ  0.965363
# 18  QBac9-Ii6jR-yLsQ5MVTHg  eV5usRjY2cDqNKVv8wXroA       Sam  0.905077
# 19  QBac9-Ii6jR-yLsQ5MVTHg  zkKv10FEw-iWJBHvK0mGfA      Paul  0.903733
#
#     review_count
# 0             34
# 1            135
# 2             57
# 3             82
# 4            112
# 5             46
# 6            101
# 7            221
# 8             73
# 9            349
# 10           142
# 11           442
# 12            83
# 13           264
# 14           334
# 15            33
# 16           343
# 17            90
# 18           105
# 19            55

# %%
pd_review_df = review_df.toPandas()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-19-3401975c75cb> in <module>()
# ----> 1 pd_review_df = review_df.toPandas()
#
# /usr/local/Cellar/apache-spark/2.3.1/libexec/python/pyspark/sql/dataframe.py in toPandas(self)
#    1966                 raise RuntimeError("%s\n%s" % (_exception_message(e), msg))
#    1967         else:
# -> 1968             pdf = pd.DataFrame.from_records(self.collect(), columns=self.columns)
#    1969
#    1970             dtype = {}
#
# /usr/local/Cellar/apache-spark/2.3.1/libexec/python/pyspark/sql/dataframe.py in collect(self)
#     464         """
#     465         with SCCallSiteSync(self._sc) as css:
# --> 466             sock_info = self._jdf.collectToPython()
#     467         return list(_load_from_socket(sock_info, BatchedSerializer(PickleSerializer())))
#     468
#
# /anaconda3/lib/python3.6/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# /usr/local/Cellar/apache-spark/2.3.1/libexec/python/pyspark/sql/utils.py in deco(*a, **kw)
#      61     def deco(*a, **kw):
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#      65             s = e.java_exception.toString()
#
# /anaconda3/lib/python3.6/site-packages/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     326                 raise Py4JJavaError(
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#     330                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling o35.collectToPython.
# : org.apache.spark.SparkException: Job 30 cancelled because SparkContext was shut down
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$cleanUpAfterSchedulerStop$1.apply(DAGScheduler.scala:837)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$cleanUpAfterSchedulerStop$1.apply(DAGScheduler.scala:835)
# 	at scala.collection.mutable.HashSet.foreach(HashSet.scala:78)
# 	at org.apache.spark.scheduler.DAGScheduler.cleanUpAfterSchedulerStop(DAGScheduler.scala:835)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onStop(DAGScheduler.scala:1841)
# 	at org.apache.spark.util.EventLoop.stop(EventLoop.scala:83)
# 	at org.apache.spark.scheduler.DAGScheduler.stop(DAGScheduler.scala:1754)
# 	at org.apache.spark.SparkContext$$anonfun$stop$8.apply$mcV$sp(SparkContext.scala:1931)
# 	at org.apache.spark.util.Utils$.tryLogNonFatalError(Utils.scala:1360)
# 	at org.apache.spark.SparkContext.stop(SparkContext.scala:1930)
# 	at org.apache.spark.SparkContext$$anonfun$2.apply$mcV$sp(SparkContext.scala:573)
# 	at org.apache.spark.util.SparkShutdownHook.run(ShutdownHookManager.scala:216)
# 	at org.apache.spark.util.SparkShutdownHookManager$$anonfun$runAll$1$$anonfun$apply$mcV$sp$1.apply$mcV$sp(ShutdownHookManager.scala:188)
# 	at org.apache.spark.util.SparkShutdownHookManager$$anonfun$runAll$1$$anonfun$apply$mcV$sp$1.apply(ShutdownHookManager.scala:188)
# 	at org.apache.spark.util.SparkShutdownHookManager$$anonfun$runAll$1$$anonfun$apply$mcV$sp$1.apply(ShutdownHookManager.scala:188)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1991)
# 	at org.apache.spark.util.SparkShutdownHookManager$$anonfun$runAll$1.apply$mcV$sp(ShutdownHookManager.scala:188)
# 	at org.apache.spark.util.SparkShutdownHookManager$$anonfun$runAll$1.apply(ShutdownHookManager.scala:188)
# 	at org.apache.spark.util.SparkShutdownHookManager$$anonfun$runAll$1.apply(ShutdownHookManager.scala:188)
# 	at scala.util.Try$.apply(Try.scala:192)
# 	at org.apache.spark.util.SparkShutdownHookManager.runAll(ShutdownHookManager.scala:188)
# 	at org.apache.spark.util.SparkShutdownHookManager$$anon$2.run(ShutdownHookManager.scala:178)
# 	at org.apache.hadoop.util.ShutdownHookManager$1.run(ShutdownHookManager.java:54)
# 	at org.apache.spark.scheduler.DAGScheduler.runJob(DAGScheduler.scala:642)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:2034)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:2055)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:2074)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:2099)
# 	at org.apache.spark.rdd.RDD$$anonfun$collect$1.apply(RDD.scala:939)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:112)
# 	at org.apache.spark.rdd.RDD.withScope(RDD.scala:363)
# 	at org.apache.spark.rdd.RDD.collect(RDD.scala:938)
# 	at org.apache.spark.sql.execution.SparkPlan.executeCollect(SparkPlan.scala:297)
# 	at org.apache.spark.sql.Dataset$$anonfun$collectToPython$1.apply(Dataset.scala:3195)
# 	at org.apache.spark.sql.Dataset$$anonfun$collectToPython$1.apply(Dataset.scala:3192)
# 	at org.apache.spark.sql.Dataset$$anonfun$52.apply(Dataset.scala:3254)
# 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId(SQLExecution.scala:77)
# 	at org.apache.spark.sql.Dataset.withAction(Dataset.scala:3253)
# 	at org.apache.spark.sql.Dataset.collectToPython(Dataset.scala:3192)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:748)
# ----------------------------------------
# Exception happened during processing of request from ('127.0.0.1', 62137)
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/socketserver.py", line 317, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/anaconda3/lib/python3.6/socketserver.py", line 348, in process_request
#     self.finish_request(request, client_address)
#   File "/anaconda3/lib/python3.6/socketserver.py", line 361, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/anaconda3/lib/python3.6/socketserver.py", line 696, in __init__
#     self.handle()
#   File "/usr/local/Cellar/apache-spark/2.3.1/libexec/python/pyspark/accumulators.py", line 235, in handle
#     num_updates = read_int(self.rfile)
#   File "/usr/local/Cellar/apache-spark/2.3.1/libexec/python/pyspark/serializers.py", line 685, in read_int
#     raise EOFError
# EOFError
# ----------------------------------------

# %%
review = pd.read_csv("/Volumes/Transcend/MDS_Yelp/yelp_review.csv")

# %%
review.user_id.isin(uids)
review[['user_id', 'business_id', 'stars', 'date']]

# %%
uids = ['nOTl4aPC4tKHK35T3bNauQ', 'QBac9-Ii6jR-yLsQ5MVTHg']
review_uid1 = review.loc[review['user_id'].isin(['nOTl4aPC4tKHK35T3bNauQ'])]
review_uid2 = review.loc[review['user_id'].isin(['PGx4HvY5joEeqXzam6tO7A'])]

# %%
merged_uid = pd.merge(review_uid1, review_uid2, how = 'inner', on = 'business_id')

# %%
merged_uid[['business_id', 'stars_x', 'stars_y', 'text_x', 'text_y', 'date_x', 'date_y']] #average the rating if more than 1 review
# Out:
#               business_id  stars_x  stars_y  \
# 0  cefRDEK5O3t_iUuwnmL27Q        4        3
# 1  pOEL97ld-FJMKO8Ki8JmYg        3        5
# 2  EjZYT46Y2qHSoChynd0q-A        4        5
# 3  _vZ7bHaGCjllogiZ7RH17w        3        4
# 4  JPgBO-7imIPdc2XBkvynpQ        4        4
# 5  S5bNE4Pmin8OQUMOFod8bQ        3        2
# 6  uF86ZhygpBEGr3CudNemYA        3        3
# 7  RkekriZhaIZ7nSJBVept6Q        4        4
#
#                                               text_x  \
# 0  We booked a reservation at Smith for Summerlic...
# 1  Okay, so my rating has gone down from the firs...
# 2  This small gallery is a bit hard to get to at ...
# 3  My sister told me that Origin was well known f...
# 4  For some reason when I heard the name of this ...
# 5  I actually think this restaurant deserves a 3-...
# 6  When deciding where to go to Valentine's Day d...
# 7  I really wanted to be blown away by this place...
#
#                                               text_y      date_x      date_y
# 0  This place looks small from the outside, but i...  2012-07-12  2016-07-31
# 1  I am a big fan of anything Oliver & Bonacini. ...  2013-10-20  2013-01-13
# 2  I love this place.  I stumbled on it when my b...  2012-11-11  2014-10-03
# 3  4.5 stars \n\nI came here with a girl friend  ...  2014-04-02  2015-04-06
# 4  Huge, huge list of Martinis.  Prices aren't ba...  2011-03-21  2015-01-03
# 5  Came here with a girl friend for dinner on a F...  2011-07-17  2012-10-28
# 6  I'm terrified of the dark and it took me a lon...  2011-11-20  2012-04-10
# 7  I've wanted to try this place for awhile and f...  2013-02-16  2012-09-23

# %%
review_uid1
# Out:
#                    review_id                 user_id             business_id  \
# 97    O4v-1NYH4-t92X-zXBWynw  nOTl4aPC4tKHK35T3bNauQ  5-Gs-cUI_8-3Ykl9KbCLsw
# 98    uRHeiP5iEnvnkN8P3gY-8A  nOTl4aPC4tKHK35T3bNauQ  uN2oZDJGO078ExbbV_DGmA
# 99    BPDhmOxSC4jk-hi9Va47cw  nOTl4aPC4tKHK35T3bNauQ  qbQ1qZx6eTy7pOOXMBfQNQ
# 100   QYw2OurOBplkQRCpYExp_w  nOTl4aPC4tKHK35T3bNauQ  XCxxPZ3Lu5mwmIo7IQRf1g
# 101   udzzB55YAxWEfVmkcZGYSA  nOTl4aPC4tKHK35T3bNauQ  VTs4f6LnUMHD4ysOezHSUQ
# 102   raUmEc0rdycXSRwXSOB5vg  nOTl4aPC4tKHK35T3bNauQ  g-OTq2Jb7FRP7cYDUlFCMg
# 103   cd5K0jPd7Gv29x_h1Hhq3Q  nOTl4aPC4tKHK35T3bNauQ  pOvTYClFgMm-wAXPW1CnhQ
# 104   V6z_U8AA-35-pp7GMPRDBw  nOTl4aPC4tKHK35T3bNauQ  OwYElCdiJ1IGKVJ4--_mvQ
# 105   PRj0OFgJjN5ljpeDskP_Tw  nOTl4aPC4tKHK35T3bNauQ  6Q7-wkCPc1KF75jZLOTcMw
# 106   gWkXKIpYPk0HJGzwZf5bng  nOTl4aPC4tKHK35T3bNauQ  NUHNLaMg7aMesMdAiie73w
# 107   3UI7I5dd8eKrlQiJ09LqLQ  nOTl4aPC4tKHK35T3bNauQ  ghWwqlRd1MaWz8hfgZ8Vsw
# 108   TYkxJGu6jAhXDA5puuzziQ  nOTl4aPC4tKHK35T3bNauQ  aNNOpMame_VEIIZUQ8m5HQ
# 109   f17tpJXCwTE0M137d9yX6g  nOTl4aPC4tKHK35T3bNauQ  zgQHtqX0gqMw1nlBZl2VnQ
# 110   YWcQnNQnBx2BbSZ8H1q5tA  nOTl4aPC4tKHK35T3bNauQ  cefRDEK5O3t_iUuwnmL27Q
# 111   Iw-bsaG215bJVdmlI4UfRg  nOTl4aPC4tKHK35T3bNauQ  pmOlcFQg9Vs3ONHpVNNXjA
# 112   AEVvtA58WlzFMbMvtwjrIg  nOTl4aPC4tKHK35T3bNauQ  pOEL97ld-FJMKO8Ki8JmYg
# 113   o-uJP0YZbD9X8_0IQPpGlA  nOTl4aPC4tKHK35T3bNauQ  RXaxKQJtExnRZX1inf8Nyg
# 114   JeIDwMKMsIPw6H6Q-B5ocA  nOTl4aPC4tKHK35T3bNauQ  3VK_NJI6mlT4LMrrM0uJiw
# 115   M_4UupfSUoept2sZHa8M0g  nOTl4aPC4tKHK35T3bNauQ  ogSBjY4agU0KDQJ2LOAc0g
# 116   ULrEMquQF4ojNkTZMh6WiA  nOTl4aPC4tKHK35T3bNauQ  EMx7IiWJK6KjQZNEAEbpow
# 117   nXFan6mWQmMy4I2WOUTYgw  nOTl4aPC4tKHK35T3bNauQ  -dy1d0ohs4D8qkJoenHNJA
# 118   4mYUDAHM-z_uf37NHryQPw  nOTl4aPC4tKHK35T3bNauQ  kGOr_D-LNpgZ2M9N8TT4QQ
# 119   DdrJIdkMm9jOSNzUGIHJTg  nOTl4aPC4tKHK35T3bNauQ  oQylTvXwGIkKFdCjmafKVg
# 120   cxZaVX0Jf3SWJqUDWnca5Q  nOTl4aPC4tKHK35T3bNauQ  EjZYT46Y2qHSoChynd0q-A
# 121   qjRyKiV9DqjVILe4-KZhsQ  nOTl4aPC4tKHK35T3bNauQ  M8_C-be43AQsH_sEgLPFPg
# 122   QgSf2JvYz-M4PU2yuJjxNQ  nOTl4aPC4tKHK35T3bNauQ  9Jc3W0aR9Xf2gcHI0rEXsw
# 123   gN6GARS_BRr5UX2D3WAH0w  nOTl4aPC4tKHK35T3bNauQ  xVEtGucSRLk5pxxN0t4i6g
# 124   ajQqbeiuBt3R8eTwl6rcBA  nOTl4aPC4tKHK35T3bNauQ  6Toez65egZSMV1iohQWGIQ
# 125   41bCWLhtGU3I0qHVHEtW6Q  nOTl4aPC4tKHK35T3bNauQ  DGkjLTH7BiHp_sMgUExYCQ
# 126   YLGx6D1zdJdwItx3mKf9lA  nOTl4aPC4tKHK35T3bNauQ  dSPR-58U95ufvmbvxMpKZg
# ...                      ...                     ...                     ...
# 175   OBu76cKovAFfaaRxKQpDDQ  nOTl4aPC4tKHK35T3bNauQ  NOz8W_cUV3Dw5yLgFkKLGw
# 176   13bbzJNpepRjlBrYdEd4Ig  nOTl4aPC4tKHK35T3bNauQ  pvCcrHFAGCml492qoQBsQg
# 1423  QDnzyYyAkAagqquEFvZU2A  nOTl4aPC4tKHK35T3bNauQ  dw2ST-AHUbu2xq0QNfngBA
# 1424  2-qdkikIVdeEmFGCCI5AFg  nOTl4aPC4tKHK35T3bNauQ  nvbfWYxTNq5XgJkcAPcXNQ
# 1425  ma2awrtPcuv49yVHiJDW6g  nOTl4aPC4tKHK35T3bNauQ  VxrvGKfba7rBDNLjc-Wy3A
# 1426  4Go3OWGbG6dJGoMmJNw_gA  nOTl4aPC4tKHK35T3bNauQ  BpJlQ1yJKSL_hMSlm1dKHQ
# 1427  GzPQarrGPtszyfZS_5Zkcw  nOTl4aPC4tKHK35T3bNauQ  OlfbvyzbncsZBAMetgPSyQ
# 1428  8ksaJ4wO1WM8lzKsAmhfyQ  nOTl4aPC4tKHK35T3bNauQ  WnUttoJffplgWaQGR2J2Xw
# 1429  m-B84SM1su5L5HsSwjKP9w  nOTl4aPC4tKHK35T3bNauQ  Vg4N2DsGrzzoam9jS1L3Wg
# 1430  PF1mydT-1gAiqJBrrCVoGw  nOTl4aPC4tKHK35T3bNauQ  RkekriZhaIZ7nSJBVept6Q
# 1431  rA7-SYY4vT1fnzHhF7I7Og  nOTl4aPC4tKHK35T3bNauQ  Ze4VPogvcD7inc3QuvY_yg
# 1432  nPUyiWHWLGhKsEhD-v7CGQ  nOTl4aPC4tKHK35T3bNauQ  TzpqNdtAZHXuIKf2xS0o2A
# 1433  n0x1e9Vw1KQU9wm3BqCtag  nOTl4aPC4tKHK35T3bNauQ  kj4xzhQX55ajTFe9DG0YLw
# 1434  1QAOkfvf6ZCD9qmuxUqDCg  nOTl4aPC4tKHK35T3bNauQ  HWl2EbZhkhAkFgqt44yUkA
# 1435  UAxfedO-ATX4WVg-yEemag  nOTl4aPC4tKHK35T3bNauQ  aLSMyYyPEuKaDrrTrwYOEg
# 1436  14XLfKARcEouXFFCqoKq8w  nOTl4aPC4tKHK35T3bNauQ  D-lzSVYyaobiguo7tfSzWw
# 1437  okx3ArLeiTcpO2_DR61cJg  nOTl4aPC4tKHK35T3bNauQ  IRd0jvnfJ3tV6AMlYMajzw
# 1438  sY40Yw_QMXMnpKYxaCgnIw  nOTl4aPC4tKHK35T3bNauQ  u2ETlHOcFdRz4BxcdfsK0Q
# 1439  stoa0xNLzh95t7UULoM6LA  nOTl4aPC4tKHK35T3bNauQ  OIdOJaNS8M624F58XGV3PQ
# 1440  6d7Os4WJsHEGWcgfu6xrSQ  nOTl4aPC4tKHK35T3bNauQ  pym03Nj6-X1Of3xa9mfPWg
# 1441  JRG9J7hiWZkBedVgNS95fQ  nOTl4aPC4tKHK35T3bNauQ  tjKpw0PIymLyd5dWTYh2aQ
# 1442  D9b03GHjhb9JB2Qe-PvDag  nOTl4aPC4tKHK35T3bNauQ  ke2VvoVX_aVJXqZLBAsEtA
# 1443  9XvmNgrTSXPP2Z41WYs22w  nOTl4aPC4tKHK35T3bNauQ  SlBl7jXhgv85tkuoTz9IOw
# 1444  8MswyU_DczhX-ecW4Y4-mA  nOTl4aPC4tKHK35T3bNauQ  MW5-SwvOFrik_A0QqarPlw
# 1445  pbzipurKGdkfXQ4LY42zjA  nOTl4aPC4tKHK35T3bNauQ  FdRZWQ8TVuKANFXcI1Do7Q
# 1446  onjwhlJ8g2SH_kYoxBNo8A  nOTl4aPC4tKHK35T3bNauQ  4jg8f82iP4lpjqZcf662HA
# 1447  tONycAt6ZC4QXeNqZHswMg  nOTl4aPC4tKHK35T3bNauQ  HudCKBs3crW5mjaD7Y89gQ
# 1448  VPJkchSdRZX7rNORZ7TPYQ  nOTl4aPC4tKHK35T3bNauQ  e2WWzD4UkPw7g8UAqe3nHQ
# 1449  euToOCwZKovAVzKntTLvKA  nOTl4aPC4tKHK35T3bNauQ  x3QeZrO_zEzuYzkj2YqBAQ
# 1450  mz7h6JsgmojE0LqnzknsFw  nOTl4aPC4tKHK35T3bNauQ  _kXHHT8RMqx9Ro8gWXE9kA
#
#       stars        date                                               text  \
# 97        4  2011-05-06  I started going to this nail salon last summer...
# 98        1  2012-06-03  I give up on this place! I have gotten burrito...
# 99        2  2011-06-22  I think I may have been let down by this place...
# 100       4  2016-01-24  This place is always solid and the customer se...
# 101       4  2012-07-08  Sometimes it feels SO good to be SO bad...for ...
# 102       3  2012-04-15  I have since switched hairdressers and am goin...
# 103       2  2016-05-22  I have eaten at several of these chains, every...
# 104       1  2012-12-04  This whole place basically sucks and it's even...
# 105       2  2012-08-22  Okay, so from what I am reading, a lot of othe...
# 106       3  2013-03-29  OK is sort of the perfect description of this ...
# 107       3  2013-04-07  We wanted something sweet for dessert, so afte...
# 108       1  2014-10-17  Pandora charms are great, but not at this loca...
# 109       2  2013-10-19  While I really enjoyed the noodles, their sign...
# 110       4  2012-07-12  We booked a reservation at Smith for Summerlic...
# 111       2  2013-02-21  A couple of weeks ago I was watching Diner's, ...
# 112       3  2013-10-20  Okay, so my rating has gone down from the firs...
# 113       2  2011-08-20  We ended up here because MoRoCo had rented out...
# 114       4  2011-03-26  Seems silly to write a review about an establi...
# 115       4  2013-03-06  Poor Hero Burger is getting a lot of flack fro...
# 116       2  2011-11-20  Basically I have been here two times, both for...
# 117       1  2013-10-19  No...I've had it with this place. I refuse to ...
# 118       5  2013-01-27  I went here with my husband and another couple...
# 119       4  2013-02-10  We went here after dinner, simply for drinks. ...
# 120       4  2012-11-11  This small gallery is a bit hard to get to at ...
# 121       5  2013-01-11  I was so surprised to see the negative reviews...
# 122       1  2012-08-23  After being scared away from Rock & Rita's, we...
# 123       5  2012-08-23  We got recommendations for this place from my ...
# 124       4  2011-08-17  I went here for the first time yesterday night...
# 125       1  2011-03-26  Worst experience EVER! I had been there before...
# 126       2  2012-12-21  I LOVE cupcakes. Seriously....LOVE affair! So ...
# ...     ...         ...                                                ...
# 175       4  2012-04-15  This place does burgers. It does them lots and...
# 176       4  2013-08-28  WHY is this place not closer to me?? Actually,...
# 1423      4  2013-02-11  Joey's sort of reminds me of a slightly more u...
# 1424      3  2011-04-03  I mean, this place is what it is - a fast-food...
# 1425      4  2013-02-10  This is a really good find! It's a small, litt...
# 1426      1  2013-04-03  This is a case of knocking it before I try it,...
# 1427      4  2012-11-04  Okay, so this is a review of the THEATRE, not ...
# 1428      3  2012-11-04  A friend and I were looking for a place to eat...
# 1429      2  2013-05-01  I was in an in-service in this area today. Whe...
# 1430      4  2013-02-16  I really wanted to be blown away by this place...
# 1431      4  2013-01-30  Okay, this is not some fine, dinning establish...
# 1432      4  2012-08-23  You know what, for what it is, it was pretty g...
# 1433      5  2015-02-07  This place was recommended to be by other shop...
# 1434      3  2012-08-23  It was late at night on The Strip, we had been...
# 1435      4  2012-06-18  I sort of want to give this place 3-1\/2 stars...
# 1436      3  2011-06-17  This is a pretty good burger place, that COULD...
# 1437      4  2012-04-15  When I worked in the area, we would treat ours...
# 1438      3  2012-07-08  We went here for Summerlicious. For $25 we got...
# 1439      4  2012-11-11  Really this deserves a 3-1\/2 star rating, but...
# 1440      4  2015-12-01  The fish and chips were delicious and flavourf...
# 1441      2  2012-06-18  I have driven past this bakery so many times a...
# 1442      3  2011-12-20  I went here for a Christmas party with fellow ...
# 1443      4  2011-12-20  We ended up here after we couldn't find a Thai...
# 1444      4  2013-02-20  This is a fun and fantastic little find in dow...
# 1445      5  2012-10-20  So I've given myself a rule that I'm going to ...
# 1446      5  2011-09-17  Since my original review I have gone back anot...
# 1447      2  2012-04-15  We had just had dinner and wanted a dessert, s...
# 1448      1  2013-07-15  My sister and I decided to spend a long weeken...
# 1449      3  2013-02-10  Exactly like the yelp 3 star saying says...thi...
# 1450      4  2012-10-08  You have to go to something like Medieval Time...
#
#       useful  funny  cool
# 97        15      1     5
# 98         2      1     0
# 99         2      0     1
# 100        0      0     0
# 101        1      0     0
# 102        3      1     0
# 103        1      0     0
# 104       11     10     3
# 105        3      1     1
# 106        0      0     0
# 107        2      0     0
# 108        4      0     0
# 109        2      1     0
# 110        1      0     1
# 111        1      2     0
# 112        0      1     1
# 113        1      0     1
# 114        2      0     0
# 115        1      0     0
# 116        7      0     0
# 117        1      4     0
# 118        1      0     1
# 119        0      0     0
# 120        0      0     0
# 121        2      0     0
# 122        0      1     0
# 123        0      0     0
# 124        1      0     0
# 125        7      9     0
# 126        2      0     0
# ...      ...    ...   ...
# 175        0      0     0
# 176        1      1     0
# 1423       0      0     1
# 1424       4      0     0
# 1425       1      0     0
# 1426      13      5     7
# 1427       2      1     0
# 1428       0      0     1
# 1429       2      3     0
# 1430       1      0     0
# 1431       3      0     1
# 1432       0      0     0
# 1433       0      0     0
# 1434       0      0     0
# 1435       1      1     0
# 1436       2      1     1
# 1437       3      4     3
# 1438       0      0     0
# 1439       0      1     0
# 1440       0      0     1
# 1441       2      1     2
# 1442       1      1     0
# 1443       0      0     0
# 1444       3      0     0
# 1445      15     10     4
# 1446       3      0     3
# 1447       1      0     0
# 1448       1      1     0
# 1449       0      0     0
# 1450       1      1     0
#
# [108 rows x 9 columns]

# %%
import fastparquet
review_df = pd.read_parquet(data_path + 'review-small.parquet', engine='fastparquet')

# %%
review_uid1 = review.loc[review['user_id'].isin(['nOTl4aPC4tKHK35T3bNauQ'])]
review_uid2 = review.loc[review['user_id'].isin(['vJGLEHyhCs9V-5fAe-xx3w'])]
merged_uid = pd.merge(review_uid1, review_uid2, how = 'inner', on = 'business_id')
merged_uid[['business_id', 'stars_x', 'stars_y', 'text_x', 'text_y', 'date_x', 'date_y']] #average the rating if more than 1 review
# Out:
#               business_id  stars_x  stars_y  \
# 0  oQylTvXwGIkKFdCjmafKVg        4        4
# 1  5N8R7ALESZ30EoAzVJtabw        5        5
# 2  u2ETlHOcFdRz4BxcdfsK0Q        3        3
#
#                                               text_x  \
# 0  We went here after dinner, simply for drinks. ...
# 1  Went in on a whim and was not disappointed. I ...
# 2  We went here for Summerlicious. For $25 we got...
#
#                                               text_y      date_x      date_y
# 0  We came here for Mother's day as has become tr...  2013-02-10  2013-06-04
# 1  The Dirty Bird invited me back to give them an...  2016-10-17  2015-10-15
# 2  I came here for a ladies lunch with the girls ...  2012-07-08  2013-06-04

# %%
review_uid1 = review.loc[review['user_id'].isin(['nOTl4aPC4tKHK35T3bNauQ'])]
review_uid2 = review.loc[review['user_id'].isin(['ZBllYKrFzaI0I7v6Wl26Wg'])]
merged_uid = pd.merge(review_uid1, review_uid2, how = 'inner', on = 'business_id')
merged_uid[['business_id', 'stars_x', 'stars_y', 'text_x', 'text_y', 'date_x', 'date_y']] #average the rating if more than 1 review
# Out:
#               business_id  stars_x  stars_y  \
# 0  cefRDEK5O3t_iUuwnmL27Q        4        4
# 1  c78Pat78fVUBFPXYeVvbaQ        5        3
#
#                                               text_x  \
# 0  We booked a reservation at Smith for Summerlic...
# 1  I am surprised at the people complaining about...
#
#                                               text_y      date_x      date_y
# 0  I would've given it 5 stars for the food, but ...  2012-07-12  2014-05-05
# 1  Overrated. \n\nMistake: coming to Odd Seoul on...  2016-01-24  2016-03-01

# %%
review_uid1 = review.loc[review['user_id'].isin(['nOTl4aPC4tKHK35T3bNauQ'])]
review_uid2 = review.loc[review['user_id'].isin(['VVm-TFCpi9M1-k8ED0l1eA'])]
merged_uid = pd.merge(review_uid1, review_uid2, how = 'inner', on = 'business_id')
merged_uid[['business_id', 'stars_x', 'stars_y', 'text_x', 'text_y', 'date_x', 'date_y']] #average the rating if more than 1 review
# Out:
#               business_id  stars_x  stars_y  \
# 0  zgQHtqX0gqMw1nlBZl2VnQ        2        4
# 1  kGOr_D-LNpgZ2M9N8TT4QQ        5        4
# 2  W5d8iNog90R-qw43m5dGwg        5        5
# 3  OIdOJaNS8M624F58XGV3PQ        4        3
#
#                                               text_x  \
# 0  While I really enjoyed the noodles, their sign...
# 1  I went here with my husband and another couple...
# 2  I have been craving schnitzel for a LONG time,...
# 3  Really this deserves a 3-1\/2 star rating, but...
#
#                                               text_y      date_x      date_y
# 0  Actual rating 3.5\n\nLet's get my main gripe o...  2013-10-19  2014-11-22
# 1  La Societe looks as good as you'd imagine a re...  2013-01-27  2012-01-05
# 2  Had lunch here today and I'm totally sold.  Si...  2012-10-08  2012-08-12
# 3  Actually around 3.5\n\nHaven't been here in qu...  2012-11-11  2014-12-22

# %%
review_uid1 = review.loc[review['user_id'].isin(['QBac9-Ii6jR-yLsQ5MVTHg'])]
review_uid2 = review.loc[review['user_id'].isin(['eV5usRjY2cDqNKVv8wXroA'])]
merged_uid = pd.merge(review_uid1, review_uid2, how = 'inner', on = 'business_id')
merged_uid[['business_id', 'stars_x', 'stars_y', 'text_x', 'text_y', 'date_x', 'date_y']] #average the rating if more than 1 review
# Out:
#               business_id  stars_x  stars_y  \
# 0  r_BrIgzYcwo1NAuG9dLbpg        4        3
#
#                                               text_x  \
# 0  This review will be shorter than my first two....
#
#                                               text_y      date_x      date_y
# 0  Total cheap eat hipster restaurant. The food w...  2016-07-05  2016-05-02
